# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("SP_500_cleaned.csv", index_col=0, parse_dates=True)

# %%
# Let's take a brief look at the data
data.head()
# Out:
#             aroon_down  aroon_up  aroon_bandwidth  bbands_lower  bbands_upper  \
# 2020-02-12        68.0     100.0             32.0      295.8801      310.6189
# 2020-02-11         0.0     100.0            100.0      296.0548      309.5222
# 2020-02-10         4.0     100.0             96.0      296.1414      308.7516
# 2020-02-07         8.0      96.0             88.0      296.0373      308.0297
# 2020-02-06         0.0     100.0            100.0      295.9214      307.6246
#
#             bbandwidth_100       cci  macd_hist          obv      rsi  ...  \
# 2020-02-12        4.860288  130.3988     0.5621  152266495.0  66.5652  ...
# 2020-02-11        4.447791  127.2818     0.4072  150193295.0  63.8521  ...
# 2020-02-10        4.169399   98.2111     0.2969  147757389.0  63.0650  ...
# 2020-02-07        3.970553   83.4621     0.1238  145518724.0  59.8937  ...
# 2020-02-06        3.878147  111.6022     0.0321  147767681.0  63.5001  ...
#
#               sma_20    stoch  today_value  crudeoil_open  dollar_open  \
# 2020-02-12  303.2495  89.2079       310.06          51.26       98.310
# 2020-02-11  302.7885  90.4138       308.08          50.97       98.370
# 2020-02-10  302.4465  94.0582       307.52          50.87       98.170
# 2020-02-07  302.0335  88.6643       305.33          51.36       97.920
# 2020-02-06  301.7730  74.0335       306.89          51.45       97.795
#
#             fedfund_open  gold_open  treasury_3_month  treasury_10_year  \
# 2020-02-12        98.830     1567.9              1.58              1.62
# 2020-02-11        98.840     1573.0              1.57              1.59
# 2020-02-10        98.825     1573.0              1.58              1.56
# 2020-02-07        98.805     1567.6              1.56              1.59
# 2020-02-06        98.760     1556.8              1.57              1.65
#
#             tomorrow_value
# 2020-02-12          309.76
# 2020-02-11          310.06
# 2020-02-10          308.08
# 2020-02-07          307.52
# 2020-02-06          305.33
#
# [5 rows x 21 columns]

# %%
# Let's first split the data into training and test set
# We will keep the first 80% of the data as training and the remaining 20% as test data
training_row_num = int(len(data) * 0.8)
# We will take the earlier data as training data                       
training_data = data[::-1].iloc[:training_row_num, :]
test_data = data[::-1].iloc[training_row_num:, :]

# %%
training_data.head()
# Out:
#             aroon_down  aroon_up  aroon_bandwidth  bbands_lower  bbands_upper  \
# 2011-02-01         0.0     100.0            100.0       57.8037       59.7096
# 2011-02-02        12.0      96.0             84.0       57.8614       59.8129
# 2011-02-03         8.0     100.0             92.0       57.8702       59.9491
# 2011-02-04         4.0     100.0             96.0       57.9004       60.0899
# 2011-02-07         0.0     100.0            100.0       57.9307       60.2802
#
#             bbandwidth_100       cci  macd_hist        obv      rsi  ...  \
# 2011-02-01        3.243721  178.8183    -0.0395  2226406.0  65.8083  ...
# 2011-02-02        3.316785  151.2937    -0.0177  2044488.0  64.3151  ...
# 2011-02-03        3.528966  112.9154     0.0013  2188908.0  65.5768  ...
# 2011-02-04        3.711325  123.0944     0.0183  2382963.0  66.9205  ...
# 2011-02-07        3.975095  160.9721     0.0471  2618981.0  69.9167  ...
#
#              sma_20    stoch  today_value  crudeoil_open  dollar_open  \
# 2011-02-01  58.7566  51.0569      99.5604          99.24       78.130
# 2011-02-02  58.8371  54.5639      99.3938          99.84       77.500
# 2011-02-03  58.9096  69.9509      99.6437         101.09       77.615
# 2011-02-04  58.9951  85.6640      99.9102         100.47       78.345
# 2011-02-07  59.1055  92.2863     100.5417          99.27       78.485
#
#             fedfund_open  gold_open  treasury_3_month  treasury_10_year  \
# 2011-02-01         99.46     1334.0              0.15              3.48
# 2011-02-02         99.29     1343.5              0.16              3.52
# 2011-02-03         99.25     1336.0              0.14              3.58
# 2011-02-04         99.18     1356.4              0.15              3.68
# 2011-02-07         99.14     1348.1              0.16              3.68
#
#             tomorrow_value
# 2011-02-01         99.3938
# 2011-02-02         99.6437
# 2011-02-03         99.9102
# 2011-02-04        100.5417
# 2011-02-07        101.0096
#
# [5 rows x 21 columns]

# %%
y_train = training_data.iloc[:, -1]
X_train = training_data.iloc[:, :-1]

# %%
# Let's take a look at the correlations among variables to see if they might be correlated with each other
plt.subplots(figsize=(14,10))
cmap = sns.diverging_palette(133, 10, as_cmap=True)
sns.heatmap(X_train.corr(), cmap=cmap, annot=True)
plt.title("Heatmap for Variable Correlation", size = 20)
plt.savefig("var_heatmap.png")
plt.show()

# %% [markdown]
# It seems that some features are highly correlated with each other. If two values are highlt collinear, then knowing one variable will predict the other variable well.\
# This is bad for building machine learning models, because the coefficients associated with that value become hard to predict

# %%
X_train.corr()
# Out:
#                   aroon_down  aroon_up  aroon_bandwidth  bbands_lower  \
# aroon_down          1.000000 -0.533451        -0.874827     -0.058777
# aroon_up           -0.533451  1.000000         0.876428      0.044844
# aroon_bandwidth    -0.874827  0.876428         1.000000      0.059146
# bbands_lower       -0.058777  0.044844         0.059146      1.000000
# bbands_upper       -0.052328  0.052669         0.059956      0.978240
# bbandwidth_100      0.027885  0.035979         0.004732     -0.210424
# cci                -0.298448  0.390681         0.393663      0.008422
# macd_hist          -0.098113  0.139049         0.135494     -0.125173
# obv                -0.094168  0.184454         0.159253      0.653594
# rsi                -0.529379  0.639760         0.667788      0.046980
# sma_100            -0.034707  0.013531         0.027508      0.987934
# sma_20             -0.055808  0.049083         0.059883      0.994379
# stoch              -0.233425  0.345524         0.330782      0.044868
# today_value        -0.094420  0.099722         0.110868      0.951151
# crudeoil_open      -0.025597  0.098897         0.071214     -0.812592
# dollar_open        -0.021624 -0.057453        -0.020595      0.783966
# fedfund_open       -0.071122  0.116317         0.107109      0.283364
# gold_open          -0.006965 -0.006308         0.000352     -0.779789
# treasury_3_month   -0.078119  0.068789         0.083871      0.618402
# treasury_10_year   -0.045232  0.048188         0.053350      0.027350
#
#                   bbands_upper  bbandwidth_100       cci  macd_hist       obv  \
# aroon_down           -0.052328        0.027885 -0.298448  -0.098113 -0.094168
# aroon_up              0.052669        0.035979  0.390681   0.139049  0.184454
# aroon_bandwidth       0.059956        0.004732  0.393663   0.135494  0.159253
# bbands_lower          0.978240       -0.210424  0.008422  -0.125173  0.653594
# bbands_upper          1.000000       -0.007989  0.024779  -0.017225  0.678105
# bbandwidth_100       -0.007989        1.000000  0.080461   0.610758  0.032054
# cci                   0.024779        0.080461  1.000000   0.385200  0.119037
# macd_hist            -0.017225        0.610758  0.385200   1.000000  0.009002
# obv                   0.678105        0.032054  0.119037   0.009002  1.000000
# rsi                   0.100298        0.257931  0.788103   0.372730  0.225720
# sma_100               0.980752       -0.140741  0.010143  -0.031626  0.636258
# sma_20                0.994709       -0.108267  0.016816  -0.070769  0.669687
# stoch                 0.056745        0.051509  0.742335   0.376413  0.124044
# bbandwidth_100           -0.082073          0.071823
# cci                       0.080446          0.022838
# macd_hist                -0.021796         -0.048976
# obv                       0.325583          0.330844
# rsi                       0.114406          0.115611
# sma_100                   0.621590         -0.003462
# sma_20                    0.620137          0.037255
# stoch                     0.061530          0.012262
# today_value               0.766668          0.035662
# crudeoil_open            -0.512218          0.299439
# dollar_open               0.407361         -0.296770
# fedfund_open              0.112439         -0.395544
# gold_open                -0.224414         -0.218881
# treasury_3_month          1.000000          0.137089
# treasury_10_year          0.137089          1.000000

# %%
# Let's find variable pairs that have high correlations
def create_corr_table(dataset):
    X_train_corr_table = dataset.corr()
    corr_var_pairs = {}
    for y in X_train_corr_table.columns:
        for x in X_train_corr_table.index:
            if (abs(X_train_corr_table.loc[x, y]) > 0.9) and x!=y:
                corr_var_pairs[(x, y)] = X_train_corr_table.loc[x, y]
    return corr_var_pairs

# %%
corr_var_pairs = create_corr_table(X_train)

# %%
corr_var_pairs_series = pd.Series(corr_var_pairs)

# %%
corr_var_pairs_series
# Out:
# bbands_upper   bbands_lower     0.978240
# sma_100        bbands_lower     0.987934
# sma_20         bbands_lower     0.994379
# today_value    bbands_lower     0.951151
# bbands_lower   bbands_upper     0.978240
# sma_100        bbands_upper     0.980752
# sma_20         bbands_upper     0.994709
# today_value    bbands_upper     0.951193
# bbands_lower   sma_100          0.987934
# bbands_upper   sma_100          0.980752
# sma_20         sma_100          0.989686
# today_value    sma_100          0.952550
# bbands_lower   sma_20           0.994379
# bbands_upper   sma_20           0.994709
# sma_100        sma_20           0.989686
# today_value    sma_20           0.956388
# bbands_lower   today_value      0.951151
# bbands_upper   today_value      0.951193
# sma_100        today_value      0.952550
# sma_20         today_value      0.956388
# dollar_open    crudeoil_open   -0.936165
# crudeoil_open  dollar_open     -0.936165
# dtype: float64

# %%
# It seems that bbands_lower and bbands_higher are correlated with many other variables
# Let's see what will happen if we remove bbands_upper and bbands_lower
pd.Series(create_corr_table(X_train.drop(["bbands_upper", "bbands_lower"], axis=1)))
# Out:
# sma_20         sma_100          0.989686
# today_value    sma_100          0.952550
# sma_100        sma_20           0.989686
# today_value    sma_20           0.956388
# sma_100        today_value      0.952550
# sma_20         today_value      0.956388
# dollar_open    crudeoil_open   -0.936165
# crudeoil_open  dollar_open     -0.936165
# dtype: float64

# %% [markdown]
# Now it seems that simple moving averages are strongly correlated with each other as well as with today's value, and dollar open values are strongly and negatively correlated with crudeoil open values

# %% [markdown]
# I will remove some features with very high correlation with other features

# %%
# Let's find feature importance with random forest regressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
variable_feature_importance = {}
for i in range(len(X_train.columns)):
    variable_feature_importance[X_train.columns[i]] = rf.feature_importances_[i]

# %%
# Let's look at the ordered feature importance of all variables currently available for the training set
pd.Series(variable_feature_importance).sort_values(ascending=False)
# Out:
# today_value         0.801891
# sma_100             0.118033
# sma_20              0.032455
# bbands_upper        0.018160
# fedfund_open        0.013297
# bbands_lower        0.010021
# obv                 0.003681
# treasury_3_month    0.001810
# dollar_open         0.000091
# gold_open           0.000070
# bbandwidth_100      0.000069
# treasury_10_year    0.000066
# crudeoil_open       0.000061
# rsi                 0.000060
# stoch               0.000048
# macd_hist           0.000046
# cci                 0.000043
# aroon_down          0.000037
# aroon_up            0.000034
# aroon_bandwidth     0.000026
# dtype: float64
