# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import time
import sys
# Machine Learning model
from sklearn.ensemble import RandomForestRegressor

# Decomposition methods
from sklearn.decomposition import FactorAnalysis
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.decomposition import TruncatedSVD

# Evaluation metrics
from sklearn.metrics import mean_squared_error


# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("SP_500_cleaned.csv", index_col=0, parse_dates=True)

# %%
# Let's take a brief look at the data
data.head()
# Out:
#             aroon_down  aroon_up  aroon_bandwidth  bbands_lower  bbands_upper  \
# 2020-02-12        68.0     100.0             32.0      295.8801      310.6189
# 2020-02-11         0.0     100.0            100.0      296.0548      309.5222
# 2020-02-10         4.0     100.0             96.0      296.1414      308.7516
# 2020-02-07         8.0      96.0             88.0      296.0373      308.0297
# 2020-02-06         0.0     100.0            100.0      295.9214      307.6246
#
#             bbandwidth_100       cci  macd_hist          obv      rsi  ...  \
# 2020-02-12        4.860288  130.3988     0.5621  152266495.0  66.5652  ...
# 2020-02-11        4.447791  127.2818     0.4072  150193295.0  63.8521  ...
# 2020-02-10        4.169399   98.2111     0.2969  147757389.0  63.0650  ...
# 2020-02-07        3.970553   83.4621     0.1238  145518724.0  59.8937  ...
# 2020-02-06        3.878147  111.6022     0.0321  147767681.0  63.5001  ...
#
#               sma_20    stoch  today_value  crudeoil_open  dollar_open  \
# 2020-02-12  303.2495  89.2079       310.06          51.26       98.310
# 2020-02-11  302.7885  90.4138       308.08          50.97       98.370
# 2020-02-10  302.4465  94.0582       307.52          50.87       98.170
# 2020-02-07  302.0335  88.6643       305.33          51.36       97.920
# 2020-02-06  301.7730  74.0335       306.89          51.45       97.795
#
#             fedfund_open  gold_open  treasury_3_month  treasury_10_year  \
# 2020-02-12        98.830     1567.9              1.58              1.62
# 2020-02-11        98.840     1573.0              1.57              1.59
# 2020-02-10        98.825     1573.0              1.58              1.56
# 2020-02-07        98.805     1567.6              1.56              1.59
# 2020-02-06        98.760     1556.8              1.57              1.65
#
#             tomorrow_value
# 2020-02-12          309.76
# 2020-02-11          310.06
# 2020-02-10          308.08
# 2020-02-07          307.52
# 2020-02-06          305.33
#
# [5 rows x 21 columns]

# %%
# Let's first split the data into training and test set
# We will keep the first 60% of the data as training and the remaining 20% as test data
training_row_num = int(len(data) * 0.6)
validation_row_num = int(len(data) * 0.8)
# We will take the earlier data as training data                       
training_data = data[::-1].iloc[:training_row_num, :]
validation_data = data[::-1].iloc[training_row_num:validation_row_num, :]
test_data = data[::-1].iloc[validation_row_num:, :]

# %%
training_data.head()
# Out:
#             aroon_down  aroon_up  aroon_bandwidth  bbands_lower  bbands_upper  \
# 2011-02-01         0.0     100.0            100.0       57.8037       59.7096
# 2011-02-02        12.0      96.0             84.0       57.8614       59.8129
# 2011-02-03         8.0     100.0             92.0       57.8702       59.9491
# 2011-02-04         4.0     100.0             96.0       57.9004       60.0899
# 2011-02-07         0.0     100.0            100.0       57.9307       60.2802
#
#             bbandwidth_100       cci  macd_hist        obv      rsi  ...  \
# 2011-02-01        3.243721  178.8183    -0.0395  2226406.0  65.8083  ...
# 2011-02-02        3.316785  151.2937    -0.0177  2044488.0  64.3151  ...
# 2011-02-03        3.528966  112.9154     0.0013  2188908.0  65.5768  ...
# 2011-02-04        3.711325  123.0944     0.0183  2382963.0  66.9205  ...
# 2011-02-07        3.975095  160.9721     0.0471  2618981.0  69.9167  ...
#
#              sma_20    stoch  today_value  crudeoil_open  dollar_open  \
# 2011-02-01  58.7566  51.0569      99.5604          99.24       78.130
# 2011-02-02  58.8371  54.5639      99.3938          99.84       77.500
# 2011-02-03  58.9096  69.9509      99.6437         101.09       77.615
# 2011-02-04  58.9951  85.6640      99.9102         100.47       78.345
# 2011-02-07  59.1055  92.2863     100.5417          99.27       78.485
#
#             fedfund_open  gold_open  treasury_3_month  treasury_10_year  \
# 2011-02-01         99.46     1334.0              0.15              3.48
# 2011-02-02         99.29     1343.5              0.16              3.52
# 2011-02-03         99.25     1336.0              0.14              3.58
# 2011-02-04         99.18     1356.4              0.15              3.68
# 2011-02-07         99.14     1348.1              0.16              3.68
#
#             tomorrow_value
# 2011-02-01         99.3938
# 2011-02-02         99.6437
# 2011-02-03         99.9102
# 2011-02-04        100.5417
# 2011-02-07        101.0096
#
# [5 rows x 21 columns]

# %%
validation_data.head()
# Out:
#             aroon_down  aroon_up  aroon_bandwidth  bbands_lower  bbands_upper  \
# 2016-07-01        84.0      32.0            -52.0      185.3541      196.8349
# 2016-07-05        80.0      28.0            -52.0      185.3635      196.5655
# 2016-07-06        76.0      24.0            -52.0      185.4288      196.3182
# 2016-07-07        72.0      20.0            -52.0      185.5661      195.9219
# 2016-07-08        68.0     100.0             32.0      185.4989      196.0521
#
#             bbandwidth_100       cci  macd_hist         obv      rsi  ...  \
# 2016-07-01        6.007918   86.6485     0.0090  13719997.0  54.7954  ...
# 2016-07-05        5.866012   39.1422     0.0923  11486970.0  51.6059  ...
# 2016-07-06        5.705035   50.0235     0.2144  13684858.0  54.0185  ...
# 2016-07-07        5.429162   65.6392     0.2735  11979915.0  53.6869  ...
# 2016-07-08        5.531738  119.1989     0.4842  14028461.0  59.6748  ...
#
#               sma_20    stoch  today_value  crudeoil_open  dollar_open  \
# 2016-07-01  191.0945  63.7571     179.7160          52.38       95.905
# 2016-07-05  190.9645  81.8494     178.4563          53.22       95.745
# 2016-07-06  190.8735  88.1325     179.5107          51.34       96.405
# 2016-07-07  190.7440  85.5009     179.3894          52.04       96.195
# 2016-07-08  190.7755  83.5353     182.1141          49.81       96.320
#
#             fedfund_open  gold_open  treasury_3_month  treasury_10_year  \
# 2016-07-01        99.580     1329.1              0.28              1.46
# 2016-07-05        99.520     1345.0              0.28              1.37
# 2016-07-06        99.580     1363.5              0.27              1.38
# 2016-07-07        99.535     1369.2              0.29              1.40
# 2016-07-08        99.525     1364.2              0.28              1.37
#
#             tomorrow_value
# 2016-07-01        178.4563
# 2016-07-05        179.5107
# 2016-07-06        179.3894
# 2016-07-07        182.1141
# 2016-07-08        182.7486
#
# [5 rows x 21 columns]

# %%
test_data.head()
# Out:
#             aroon_down  aroon_up  aroon_bandwidth  bbands_lower  bbands_upper  \
# 2018-04-24        36.0       0.0            -36.0      236.2465      249.2235
# 2018-04-25        32.0       4.0            -28.0      236.5744      249.1816
# 2018-04-26        28.0       0.0            -28.0      237.1444      249.2136
# 2018-04-27        24.0      72.0             48.0      237.2629      249.3791
# 2018-04-30        20.0      68.0             48.0      238.4509      248.8351
#
#             bbandwidth_100      cci  macd_hist         obv      rsi  ...  \
# 2018-04-24        5.346159 -60.8306     0.3600  69353660.0  44.0935  ...
# 2018-04-25        5.190754 -85.2170     0.1701  71708198.0  45.2870  ...
# 2018-04-26        4.963093  -5.9146     0.2079  73814989.0  49.9120  ...
# 2018-04-27        4.979513   1.9691     0.2436  75993857.0  50.3836  ...
# 2018-04-30        4.262056 -39.0317     0.1314  73847756.0  46.7379  ...
#
#              sma_20    stoch  today_value  crudeoil_open  dollar_open  \
# 2018-04-24  242.735  37.5990     233.2478          63.43       90.275
# 2018-04-25  242.878  25.9076     233.8465          62.77       90.120
# 2018-04-26  243.179  26.7405     236.2509          63.20       90.525
# 2018-04-27  243.321  40.3641     236.5020          62.97       90.950
# 2018-04-30  243.643  54.9364     234.5707          62.97       90.955
#
#             fedfund_open  gold_open  treasury_3_month  treasury_10_year  \
# 2018-04-24        97.490     1323.2              1.87              3.00
# 2018-04-25        97.495     1328.6              1.85              3.03
# 2018-04-26        97.500     1320.7              1.82              3.00
# 2018-04-27        97.495     1318.0              1.82              2.96
# 2018-04-30        97.490     1324.0              1.87              2.95
#
#             tomorrow_value
# 2018-04-24        233.8465
# 2018-04-25        236.2509
# 2018-04-26        236.5020
# 2018-04-27        234.5707
# 2018-04-30        235.0728
#
# [5 rows x 21 columns]

# %%
y_train = training_data.iloc[:, -1]
X_train = training_data.iloc[:, :-1]
y_validation = validation_data.iloc[:, -1]
X_validation = validation_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]

# %%
# Let's take a look at the correlations among variables to see if they might be correlated with each other

plt.subplots(figsize=(14,10))
cmap = sns.diverging_palette(133, 10, as_cmap=True)
sns.heatmap(X_train.corr(), cmap=cmap, annot=True)
plt.title("Heatmap for Variable Correlation", size = 20)
plt.savefig("var_heatmap.png")
plt.show()

# %% [markdown]
# It seems that some features are highly correlated with each other. If two values are highlt collinear, then knowing one variable will predict the other variable well.\
# This is bad for building machine learning models, because the coefficients associated with that value become hard to predict

# %%
X_train.corr()
# Out:
#                   aroon_down  aroon_up  aroon_bandwidth  bbands_lower  \
# aroon_down          1.000000 -0.534317        -0.876207      0.006655
# aroon_up           -0.534317  1.000000         0.875545     -0.017662
# aroon_bandwidth    -0.876207  0.875545         1.000000     -0.013874
# bbands_lower        0.006655 -0.017662        -0.013874      1.000000
# bbands_upper        0.005015 -0.001503        -0.003723      0.964389
# bbandwidth_100      0.004345  0.055235         0.029009     -0.186725
# cci                -0.266412  0.375745         0.366502     -0.075394
# macd_hist          -0.058115  0.124021         0.103927     -0.164097
# obv                -0.058885  0.187685         0.140665      0.735837
# rsi                -0.496101  0.626277         0.640625     -0.074127
# sma_100             0.030713 -0.056796        -0.049937      0.980058
# sma_20              0.005870 -0.009494        -0.008768      0.990668
# stoch              -0.214150  0.326887         0.308775     -0.009556
# today_value        -0.023982  0.046261         0.040083      0.944194
# crudeoil_open      -0.101695  0.214667         0.180518     -0.731708
# dollar_open         0.059675 -0.146453        -0.117608      0.752175
# fedfund_open       -0.070286  0.123857         0.110790      0.277090
# gold_open          -0.054279  0.026676         0.046234     -0.847834
# treasury_3_month   -0.040268 -0.025255         0.008617      0.171117
# treasury_10_year   -0.033454  0.059093         0.052813     -0.024939
#
#                   bbands_upper  bbandwidth_100       cci  macd_hist       obv  \
# aroon_down            0.005015        0.004345 -0.266412  -0.058115 -0.058885
# aroon_up             -0.001503        0.055235  0.375745   0.124021  0.187685
# aroon_bandwidth      -0.003723        0.029009  0.366502   0.103927  0.140665
# bbands_lower          0.964389       -0.186725 -0.075394  -0.164097  0.735837
# bbands_upper          1.000000        0.074676 -0.047443  -0.012117  0.754283
# bbandwidth_100        0.074676        1.000000  0.105075   0.652360  0.038861
# cci                  -0.047443        0.105075  1.000000   0.346137  0.082786
# macd_hist            -0.012117        0.652360  0.346137   1.000000  0.015584
# obv                   0.754283        0.038861  0.082786   0.015584  1.000000
# rsi                   0.012522        0.322521  0.782732   0.340628  0.203955
# sma_100               0.968092       -0.096894 -0.071758  -0.036319  0.707237
# sma_20                0.991438       -0.053704 -0.061670  -0.087259  0.751979
# stoch                 0.009580        0.067774  0.750756   0.332633  0.113198
# today_value           0.948942       -0.038848  0.011382   0.000352  0.769046
# crudeoil_open        -0.733660        0.037257  0.120928   0.012864 -0.267575
# dollar_open           0.745047       -0.081136 -0.080149  -0.012447  0.368676
# fedfund_open          0.283223       -0.002825  0.120463   0.022549  0.269180
# gold_open            -0.863737        0.002699  0.068366   0.042447 -0.714498
# treasury_3_month      0.169634       -0.042092 -0.015472  -0.030956 -0.317166
# treasury_10_year     -0.007444        0.063635  0.010193  -0.043090  0.236070
#
#                        rsi   sma_100    sma_20     stoch  today_value  \
# aroon_down       -0.496101  0.030713  0.005870 -0.214150    -0.023982
# aroon_up          0.626277 -0.056796 -0.009494  0.326887     0.046261
# aroon_bandwidth   0.640625 -0.049937 -0.008768  0.308775     0.040083
# bbands_lower     -0.074127  0.980058  0.990668 -0.009556     0.944194
# bbands_upper      0.012522  0.968092  0.991438  0.009580     0.948942
# bbandwidth_100    0.322521 -0.096894 -0.053704  0.067774    -0.038848
# cci               0.782732 -0.071758 -0.061670  0.750756     0.011382
# macd_hist         0.340628 -0.036319 -0.087259  0.332633     0.000352
# obv               0.203955  0.707237  0.751979  0.113198     0.769046
# rsi               1.000000 -0.109069 -0.030144  0.639351     0.051268
# sma_100          -0.109069  1.000000  0.982731 -0.005449     0.948587
# sma_20           -0.030144  0.982731  1.000000  0.000219     0.955157
# stoch             0.639351 -0.005449  0.000219  1.000000     0.064538
# today_value       0.051268  0.948587  0.955157  0.064538     1.000000
# crudeoil_open     0.218382 -0.783025 -0.739314  0.063806    -0.759147
# dollar_open      -0.151040  0.796771  0.755286 -0.022520     0.809933
# fedfund_open      0.170156  0.268744  0.282750  0.116018     0.345610
# gold_open         0.022462 -0.845750 -0.863676 -0.003435    -0.885512
# treasury_3_month -0.021192  0.183580  0.171896  0.001606     0.207484
# treasury_10_year  0.124337 -0.072431 -0.016148  0.024853    -0.078431
#
#                   crudeoil_open  dollar_open  fedfund_open  gold_open  \
# aroon_down            -0.101695     0.059675     -0.070286  -0.054279
# aroon_up               0.214667    -0.146453      0.123857   0.026676
# aroon_bandwidth        0.180518    -0.117608      0.110790   0.046234
# bbands_lower          -0.731708     0.752175      0.277090  -0.847834
# bbands_upper          -0.733660     0.745047      0.283223  -0.863737
# bbandwidth_100         0.037257    -0.081136     -0.002825   0.002699
# cci                    0.120928    -0.080149      0.120463   0.068366
# macd_hist              0.012864    -0.012447      0.022549   0.042447
# obv                   -0.267575     0.368676      0.269180  -0.714498
# rsi                    0.218382    -0.151040      0.170156   0.022462
# sma_100               -0.783025     0.796771      0.268744  -0.845750
# sma_20                -0.739314     0.755286      0.282750  -0.863676
# stoch                  0.063806    -0.022520      0.116018  -0.003435
# today_value           -0.759147     0.809933      0.345610  -0.885512
# crudeoil_open          1.000000    -0.942868     -0.252273   0.672125
# dollar_open           -0.942868     1.000000      0.343336  -0.720348
# fedfund_open          -0.252273     0.343336      1.000000  -0.196554
# gold_open              0.672125    -0.720348     -0.196554   1.000000
# treasury_3_month      -0.466556     0.385824      0.123541  -0.149758
# treasury_10_year       0.377773    -0.376194     -0.433963  -0.234897
#
#                   treasury_3_month  treasury_10_year
# aroon_down               -0.040268         -0.033454
# aroon_up                 -0.025255          0.059093
# aroon_bandwidth           0.008617          0.052813
# bbands_lower              0.171117         -0.024939
# bbands_upper              0.169634         -0.007444
# bbandwidth_100           -0.042092          0.063635
# cci                      -0.015472          0.010193
# macd_hist                -0.030956         -0.043090
# obv                      -0.317166          0.236070
# rsi                      -0.021192          0.124337
# sma_100                   0.183580         -0.072431
# sma_20                    0.171896         -0.016148
# stoch                     0.001606          0.024853
# today_value               0.207484         -0.078431
# crudeoil_open            -0.466556          0.377773
# dollar_open               0.385824         -0.376194
# fedfund_open              0.123541         -0.433963
# gold_open                -0.149758         -0.234897
# treasury_3_month          1.000000         -0.282017
# treasury_10_year         -0.282017          1.000000

# %%
# Let's find variable pairs that have high correlations
def create_corr_table(dataset):
    X_train_corr_table = dataset.corr()
    corr_var_pairs = {}
    for y in X_train_corr_table.columns:
        for x in X_train_corr_table.index:
            if (abs(X_train_corr_table.loc[x, y]) > 0.9) and x!=y:
                corr_var_pairs[(x, y)] = X_train_corr_table.loc[x, y]
    return corr_var_pairs

# %%
corr_var_pairs = create_corr_table(X_train)

# %%
corr_var_pairs_series = pd.Series(corr_var_pairs)

# %%
corr_var_pairs_series
# Out:
# bbands_upper   bbands_lower     0.964389
# sma_100        bbands_lower     0.980058
# sma_20         bbands_lower     0.990668
# today_value    bbands_lower     0.944194
# bbands_lower   bbands_upper     0.964389
# sma_100        bbands_upper     0.968092
# sma_20         bbands_upper     0.991438
# today_value    bbands_upper     0.948942
# bbands_lower   sma_100          0.980058
# bbands_upper   sma_100          0.968092
# sma_20         sma_100          0.982731
# today_value    sma_100          0.948587
# bbands_lower   sma_20           0.990668
# bbands_upper   sma_20           0.991438
# sma_100        sma_20           0.982731
# today_value    sma_20           0.955157
# bbands_lower   today_value      0.944194
# bbands_upper   today_value      0.948942
# sma_100        today_value      0.948587
# sma_20         today_value      0.955157
# dollar_open    crudeoil_open   -0.942868
# crudeoil_open  dollar_open     -0.942868
# dtype: float64

# %%
# It seems that bbands_lower and bbands_higher are correlated with many other variables
# Let's see what will happen if we remove bbands_upper and bbands_lower
pd.Series(create_corr_table(X_train.drop(["bbands_upper", "bbands_lower"], axis=1)))
# Out:
# sma_20         sma_100          0.982731
# today_value    sma_100          0.948587
# sma_100        sma_20           0.982731
# today_value    sma_20           0.955157
# sma_100        today_value      0.948587
# sma_20         today_value      0.955157
# dollar_open    crudeoil_open   -0.942868
# crudeoil_open  dollar_open     -0.942868
# dtype: float64

# %% [markdown]
# Now it seems that simple moving averages are strongly correlated with each other as well as with today's value, and dollar open values are strongly and negatively correlated with crudeoil open values

# %% [markdown]
# I will remove some features with very high correlation with other features

# %%
X_train.obv.plot()

# %%
# Let's find feature importance with random forest regressor
rf = RandomForestRegressor(random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
variable_feature_importance = {}
for i in range(len(X_train.columns)):
    variable_feature_importance[X_train.columns[i]] = rf.feature_importances_[i]

# %%
# Let's look at the ordered feature importance of all variables currently available for the training set
pd.Series(variable_feature_importance).sort_values(ascending=False)
# Out:
# today_value         0.756181
# sma_100             0.238485
# bbands_upper        0.002010
# sma_20              0.001738
# obv                 0.000260
# bbands_lower        0.000155
# bbandwidth_100      0.000107
# gold_open           0.000106
# stoch               0.000097
# treasury_10_year    0.000095
# rsi                 0.000094
# macd_hist           0.000090
# dollar_open         0.000084
# cci                 0.000084
# fedfund_open        0.000083
# crudeoil_open       0.000083
# aroon_down          0.000076
# aroon_up            0.000068
# aroon_bandwidth     0.000065
# treasury_3_month    0.000040
# dtype: float64

# %% [markdown]
# From the result of the feature importance, it seems that aroon variables are not important features in terms of predicting the outcome.
# * Most relevant variables are yesterday values, simple moving averages, and upper bollinger bands
# * aroon, cci, macd, stoch, rsi, crudeoil, treasury, bbandwidth, gold, dollar are the least relevant variables

# %%
# I will form a baseline model and see the rmse value for it
y_val_pred = rf.predict(X_validation)
print("root mean squared error: {}".format(np.sqrt(mean_squared_error(y_validation, y_val_pred))))
# Out:
# root mean squared error: 38.618093823820836

# %%
# Let's run another random forest model with fewer variables
kept_cols = ['today_value', 'sma_100', 'bbands_upper', 'sma_20', 'obv', 'bbands_lower',
               'bbandwidth_100', 'gold_open', 'stoch', 'treasury_10_year', 'rsi', 'macd_hist']
rf2 = RandomForestRegressor(random_state=0)
rf2.fit(X_train[kept_cols], y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
reduced_variable_feature_importance = {}
for i in range(len(kept_cols)):
    reduced_variable_feature_importance[kept_cols[i]] = rf2.feature_importances_[i]

# %%
pd.Series(reduced_variable_feature_importance).sort_values(ascending=False)
# Out:
# today_value         0.760417
# sma_100             0.234145
# sma_20              0.002289
# bbands_upper        0.001877
# obv                 0.000285
# gold_open           0.000163
# bbandwidth_100      0.000152
# rsi                 0.000148
# stoch               0.000142
# macd_hist           0.000135
# treasury_10_year    0.000131
# bbands_lower        0.000114
# dtype: float64

# %%
y_val_pred_reduced = rf2.predict(X_validation[kept_cols])
print("root mean squared error: {}".format(np.sqrt(mean_squared_error(y_validation, y_val_pred_reduced))))
# Out:
# root mean squared error: 38.990770897750984

# %% [markdown]
# The RMSE values for X_train with fewer rows are similar to RMSE values for X_train with all values.

# %% [markdown]
# #### Now here's the question. Is there any latent variables we are missing, and if we should resort to decomposition methods such as PCA, LDA, or Factor Analysis

# %% [markdown]
# We can iteratively test all these methods to see if they can yield a better rmse score than what we already achieved with the baseline model

# %%
# Let's build a function that iteratively spits out rmse score for predictions with PCA components

# %%
# Let's build a function that iteratively spits out rmse score for predictions with PCA components
def PCA_evaluation(X_train, y_train, X_validation, y_validation):
    var_num = len(X_train.columns) # Maximum number of components is equal to the number of variables
    for n_components in range(1, var_num+1):
        pca = PCA(n_components = n_components, random_state = 0)
        X_train_pca = pca.fit_transform(X_train)
        X_validation_pca = pca.transform(X_validation)
        rf = RandomForestRegressor(random_state=0)
        rf.fit(X_train_pca, y_train)
        y_val_pred = rf.predict(X_validation_pca)
        print("root mean squared error for {} components: {}".format(n_components, np.sqrt(mean_squared_error(y_validation, y_val_pred))))

# %%
# Let's see if having PCA produces lower RMSE values
PCA_evaluation(X_train, y_train, X_validation, y_validation)
# Out:
# root mean squared error for 1 components: 63.77391420112304
# root mean squared error for 2 components: 53.88652803595703
# root mean squared error for 3 components: 53.82982592577127
# root mean squared error for 4 components: 53.50255425571675
# root mean squared error for 5 components: 45.748932284724866
# root mean squared error for 6 components: 46.66566311844803
# root mean squared error for 7 components: 47.03630535243341
# root mean squared error for 8 components: 47.023348836719435
# root mean squared error for 9 components: 47.067803916226765
# root mean squared error for 10 components: 49.64906013903575
# root mean squared error for 11 components: 48.707745034944224
# root mean squared error for 12 components: 47.25470574188763
# root mean squared error for 13 components: 47.31550506619322
# root mean squared error for 14 components: 47.082537508256785
# root mean squared error for 15 components: 47.94468300595813
# root mean squared error for 16 components: 47.91843415037531
# root mean squared error for 17 components: 48.09542406530177
# root mean squared error for 18 components: 47.946653012535116
# root mean squared error for 19 components: 48.98439672037027
# root mean squared error for 20 components: 48.949845997856606

# %% [markdown]
# The RMSE values turns out to be a lot higher, meaning that PCA is not helpful for our prediction

# %%
# Let's build a function that iteratively spits out rmse score for predictions with kernel PCA components
def KernelPCA_evaluation(X_train, y_train, X_validation, y_validation):
    var_num = len(X_train.columns) # Maximum number of components is equal to the number of variables
    for n_components in range(1, var_num+1):
        kpca = KernelPCA(n_components = n_components, random_state = 0)
        X_train_kpca = kpca.fit_transform(X_train)
        X_validation_kpca = kpca.transform(X_validation)
        rf = RandomForestRegressor(random_state=0)
        rf.fit(X_train_kpca, y_train)
        y_val_pred = rf.predict(X_validation_kpca)
        print("root mean squared error for {} components: {}".format(n_components, np.sqrt(mean_squared_error(y_validation, y_val_pred))))

# %%
# Let's see if having kernel PCA produces lower RMSE values
KernelPCA_evaluation(X_train, y_train, X_validation, y_validation)
# Out:
# root mean squared error for 1 components: 63.77391420112304
# root mean squared error for 2 components: 53.88652803595703
# root mean squared error for 3 components: 53.82982075531837
# root mean squared error for 4 components: 53.50255425571675
# root mean squared error for 5 components: 45.74904527643438
# root mean squared error for 6 components: 45.827396187352356
# root mean squared error for 7 components: 45.743540700625175
# root mean squared error for 8 components: 45.74875226278474
# root mean squared error for 9 components: 45.76521045688733
# root mean squared error for 10 components: 45.777506589424064
# root mean squared error for 11 components: 45.830187906194155
# root mean squared error for 12 components: 45.778301720512005
# root mean squared error for 13 components: 45.76553969920998
# root mean squared error for 14 components: 45.76867972499473
# root mean squared error for 15 components: 45.77977394412803
# root mean squared error for 16 components: 45.82769598750537
# root mean squared error for 17 components: 45.712388069338026
# root mean squared error for 18 components: 45.71901972719109
# root mean squared error for 19 components: 45.804688166498636
# root mean squared error for 20 components: 45.753681424236255

# %%
# Let's build a function that iteratively spits out rmse score for predictions with factor analysis components
def FactorAnalysis_evaluation(X_train, y_train, X_validation, y_validation):
    var_num = len(X_train.columns) # Maximum number of components is equal to the number of variables
    for n_components in range(1, var_num+1):
        fa = FactorAnalysis(n_components = n_components, random_state = 0)
        X_train_fa = fa.fit_transform(X_train)
        X_validation_fa = fa.transform(X_validation)
        rf = RandomForestRegressor(random_state=0)
        rf.fit(X_train_fa, y_train)
        y_val_pred = rf.predict(X_validation_fa)
        print("root mean squared error for {} components: {}".format(n_components, np.sqrt(mean_squared_error(y_validation, y_val_pred))))

# %%
# Let's see if doing factor analysis produces lower RMSE values
FactorAnalysis_evaluation(X_train, y_train, X_validation, y_validation)
# Out:
# root mean squared error for 1 components: 63.77391420112304
# root mean squared error for 2 components: 41.78392493971313
# root mean squared error for 3 components: 39.169600505709525
# root mean squared error for 4 components: 40.43820430389335
# root mean squared error for 5 components: 47.721073047087295
# root mean squared error for 6 components: 56.87389237034486
# root mean squared error for 7 components: 49.250690555113145
# root mean squared error for 8 components: 45.81033280544695
# root mean squared error for 9 components: 40.44018882420514
# root mean squared error for 10 components: 51.05614742960019
# root mean squared error for 11 components: 53.65418901741286
# root mean squared error for 12 components: 45.777559479036334
# root mean squared error for 13 components: 46.75643192935163
# root mean squared error for 14 components: 44.583013068336896
# root mean squared error for 15 components: 41.37090001654525
# root mean squared error for 16 components: 41.651846215377304
# root mean squared error for 17 components: 43.241305017014916
# root mean squared error for 18 components: 41.81612403525096
# root mean squared error for 19 components: 46.14921519355619
# root mean squared error for 20 components: 46.25656072584013

# %% [markdown]
# For Factor Analysis, the RMSE overall is still higher than having original variables. When there are only 3 components, the RMSE score for factor analysis components is similar to that with origin variables

# %%
# Let's build a function that iteratively spits out rmse score for predictions with Factor TruncatedSVD components
def truncatedsvd_evaluation(X_train, y_train, X_validation, y_validation):
    var_num = len(X_train.columns) # Maximum number of components is equal to the number of variables
    for n_components in range(1, var_num):
        lda = TruncatedSVD(n_components = n_components, random_state = 0)
        X_train_tsvd = lda.fit_transform(X_train)
        X_validation_tsvd = lda.transform(X_validation)
        rf = RandomForestRegressor(random_state=0)
        rf.fit(X_train_tsvd, y_train)
        y_val_pred = rf.predict(X_validation_tsvd)
        print("root mean squared error for {} components: {}".format(n_components, np.sqrt(mean_squared_error(y_validation, y_val_pred))))

# %%
# Let's see if doing factor analysis produces lower RMSE values
truncatedsvd_evaluation(X_train, y_train, X_validation, y_validation)
# Out:
# root mean squared error for 1 components: 63.77391420112304
# root mean squared error for 2 components: 60.344017538909625
# root mean squared error for 3 components: 59.370640964779874
# root mean squared error for 4 components: 42.52385061716801
# root mean squared error for 5 components: 42.42873495870845
# root mean squared error for 6 components: 42.76118163560814
# root mean squared error for 7 components: 42.62339669542998
# root mean squared error for 8 components: 42.8694167821213
# root mean squared error for 9 components: 42.757894160659426
# root mean squared error for 10 components: 42.98176783134254
# root mean squared error for 11 components: 43.46844220620455
# root mean squared error for 12 components: 43.00655827642853
# root mean squared error for 13 components: 42.11830335133194
# root mean squared error for 14 components: 41.96704807471243
# root mean squared error for 15 components: 42.47981811024078
# root mean squared error for 16 components: 43.6225562085104
# root mean squared error for 17 components: 43.81467607699142
# root mean squared error for 18 components: 44.30131956521371
# root mean squared error for 19 components: 45.574313694576375

# %% [markdown]
# Still, the resulting RMSE is worse than the baseline RMSE

# %% [markdown]
# ### It seems that we can't really obtain good result with decomposition methods
# Instead, let's go back to orginal variables and try different combinations of them

# %%
X_train.columns
# Out:
# Index(['aroon_down', 'aroon_up', 'aroon_bandwidth', 'bbands_lower',
#        'bbands_upper', 'bbandwidth_100', 'cci', 'macd_hist', 'obv', 'rsi',
#        'sma_100', 'sma_20', 'stoch', 'today_value', 'crudeoil_open',
#        'dollar_open', 'fedfund_open', 'gold_open', 'treasury_3_month',
#        'treasury_10_year'],
#       dtype='object')

# %%
def make_combinations(data):
    num_var = len(data.columns)
    combinations = []
    for i in range(1, num_var + 1):
        for combination in itertools.combinations(data.columns, i):
            combinations.append(combination)
    return combinations
        
column_combinations = make_combinations(X_train[kept_cols])

# %%
len(column_combinations)
# Out:
# 4095

# %%
# I will make a custom function to iteratively evaluate rmse score for each variable combination

def evaluate_combinations(X_train, y_train, X_validation, y_validation, combinations, model):
    combination_evaluation = {}
    iter_num = 1
    start_time = time.perf_counter()
    for c in combinations:
        model.fit(X_train[list(c)], y_train)
        y_val_pred = model.predict(X_validation[list(c)])
        rmse = np.sqrt(mean_squared_error(y_validation, y_val_pred))
        combination_evaluation[c] = rmse
        iter_num += 1
        if iter_num % 100 == 0:
            iter_time = time.perf_counter()
            print("Iteration {}: rmse -- {}".format(iter_num, rmse))
            print("Time spent: {} seconds".format(str(round(iter_time - start_time, 2))))
    return combination_evaluation

# %%
rf = RandomForestRegressor(random_state=0, n_jobs=-1)
combination_evaluation = evaluate_combinations(X_train, y_train, X_validation, y_validation, column_combinations, rf)
# Out:
# Iteration 100: rmse -- 39.2260868335821
# Time spent: 37.08 seconds
# Iteration 200: rmse -- 40.466568161153006
# Time spent: 79.33 seconds
# Iteration 300: rmse -- 39.07735425136124
# Time spent: 118.37 seconds
# Iteration 400: rmse -- 39.35869119147736
# Time spent: 158.12 seconds
# Iteration 500: rmse -- 42.49114612336752
# Time spent: 198.29 seconds
# Iteration 600: rmse -- 45.7252790431932
# Time spent: 238.67 seconds
# Iteration 700: rmse -- 39.949374650010945
# Time spent: 277.97 seconds
# Iteration 800: rmse -- 39.122703457496684
# Time spent: 318.01 seconds
# Iteration 900: rmse -- 38.18436582048139
# Time spent: 359.13 seconds
# Iteration 1000: rmse -- 39.19124667886534
# Time spent: 401.64 seconds
# Iteration 1100: rmse -- 39.08850979359588
# Time spent: 443.07 seconds
# Iteration 1200: rmse -- 40.90528141129686
# Time spent: 485.74 seconds
# Iteration 1300: rmse -- 40.320929666900206
# Time spent: 525.56 seconds
# Iteration 1400: rmse -- 44.8982660311093
# Time spent: 568.28 seconds
# Iteration 1500: rmse -- 40.998936254753595
# Time spent: 613.95 seconds
# Iteration 1600: rmse -- 38.9539003831693
# Time spent: 661.18 seconds
# Iteration 1700: rmse -- 39.00438262180493
# Time spent: 701.05 seconds
# Iteration 1800: rmse -- 39.1221409441184
# Time spent: 741.25 seconds
# Iteration 1900: rmse -- 38.9284796102144
# Time spent: 781.67 seconds
# Iteration 2000: rmse -- 39.153087373534156
# Time spent: 820.7 seconds
# Iteration 2100: rmse -- 39.5960831195876
# Time spent: 861.23 seconds
# Iteration 2200: rmse -- 40.61913587919466
# Time spent: 902.66 seconds
# Iteration 2300: rmse -- 40.871081834530806
# Time spent: 942.08 seconds
# Iteration 2400: rmse -- 44.24152977210749
# Time spent: 984.84 seconds
# Iteration 2500: rmse -- 59.37844230821793
# Time spent: 1027.25 seconds
# Iteration 2600: rmse -- 38.48928089539898
# Time spent: 1074.0 seconds
# Iteration 2700: rmse -- 38.665521445519836
# Time spent: 1121.41 seconds
# Iteration 2800: rmse -- 38.982309953450205
# Time spent: 1170.32 seconds
# Iteration 2900: rmse -- 39.028493908832914
# Time spent: 1218.68 seconds
# Iteration 3000: rmse -- 41.35859805109028
# Time spent: 1265.42 seconds
# Iteration 3100: rmse -- 41.5043688209103
# Time spent: 1312.78 seconds
# Iteration 3200: rmse -- 40.959818224886625
# Time spent: 1359.72 seconds
# Iteration 3300: rmse -- 43.23034706639847
# Time spent: 1406.52 seconds
# Iteration 3400: rmse -- 38.51857686903487
# Time spent: 1454.39 seconds
# Iteration 3500: rmse -- 38.57993862224982
# Time spent: 1502.27 seconds
# Iteration 3600: rmse -- 39.14551715502081
# Time spent: 1549.99 seconds
# Iteration 3700: rmse -- 40.44510882778791
# Time spent: 1597.9 seconds
# Iteration 3800: rmse -- 38.89808267838834
# Time spent: 1646.86 seconds
# Iteration 3900: rmse -- 39.02440619986421
# Time spent: 1697.49 seconds
# Iteration 4000: rmse -- 40.75299821704554
# Time spent: 1745.78 seconds

# %%
pd.Series(combination_evaluation).sort_values(ascending=True)[0]
# Out:
# 36.762105309241015

# %%
for key, value in combination_evaluation.items():
    for i in range(5):
        if value == pd.Series(combination_evaluation).sort_values(ascending=True)[i]:
            print(key, value)
# Out:
# ('today_value',)
# ('today_value', 'bbands_upper')
# ('today_value', 'obv')
# ('today_value', 'rsi')
# ('today_value', 'bbands_upper', 'obv')

# %%
combination_evaluation
# Out:
# {('today_value',): 36.762105309241015,
#  ('sma_100',): 43.7470510316607,
#  ('bbands_upper',): 67.35524006123309,
#  ('sma_20',): 41.59609912757593,
#  ('obv',): 63.77391420112305,
#  ('bbands_lower',): 41.665755618434346,
#  ('bbandwidth_100',): 72.94590905881142,
#  ('gold_open',): 61.39178830302331,
#  ('stoch',): 78.30885979208291,
#  ('treasury_10_year',): 66.26151294160805,
#  ('rsi',): 78.45632826332174,
#  ('macd_hist',): 77.65428223990448,
#  ('today_value', 'sma_100'): 38.419317032113234,
#  ('today_value', 'bbands_upper'): 37.09441554730249,
#  ('today_value', 'sma_20'): 39.28980699710697,
#  ('today_value', 'obv'): 37.35158466936582,
#  ('today_value', 'bbands_lower'): 39.04463748989481,
#  ('today_value', 'bbandwidth_100'): 37.866091673777206,
#  ('today_value', 'gold_open'): 37.98016640439435,
#  ('today_value', 'stoch'): 38.328503406998664,
#  ('today_value', 'treasury_10_year'): 38.446900019952956,
#  ('today_value', 'rsi'): 37.54145999143655,
#  ('today_value', 'macd_hist'): 38.35516598112178,
#  ('sma_100', 'bbands_upper'): 54.1736820751397,
#  ('sma_100', 'sma_20'): 42.15541737946985,
#  ('sma_100', 'obv'): 47.03779190897671,
#  ('sma_100', 'bbands_lower'): 43.2897761545557,
#  ('sma_100', 'bbandwidth_100'): 46.2085476095531,
#  ('sma_100', 'gold_open'): 38.95029608600293,
#  ('sma_100', 'stoch'): 43.39577475926831,
#  ('sma_100', 'treasury_10_year'): 42.11255551380832,
#  ('sma_100', 'rsi'): 40.54928004006966,
#  ('sma_100', 'macd_hist'): 43.978231193483744,
#  ('bbands_upper', 'sma_20'): 52.294110670860206,
#  ('bbands_upper', 'obv'): 63.32625559726837,
#  ('bbands_upper', 'bbands_lower'): 41.96255039892137,
#  ('bbands_upper', 'bbandwidth_100'): 42.74693332155041,
#  ('bbands_upper', 'gold_open'): 67.84699599500459,
#  ('bbands_upper', 'stoch'): 67.92897615827688,
#  ('bbands_upper', 'treasury_10_year'): 56.60739315772837,
#  ('bbands_upper', 'rsi'): 43.827726360544645,
#  ('bbands_upper', 'macd_hist'): 66.68470655149062,
#  ('sma_20', 'obv'): 42.27443763079424,
#  ('sma_20', 'bbands_lower'): 41.648482214979495,
#  ('sma_20', 'bbandwidth_100'): 42.45140560935714,
#  ('sma_20', 'gold_open'): 39.38046997513339,
#  ('sma_20', 'stoch'): 40.22040414715887,
#  ('sma_20', 'treasury_10_year'): 41.12139557561494,
#  ('sma_20', 'rsi'): 39.61630128556105,
#  ('sma_20', 'macd_hist'): 40.46792008577158,
#  ('obv', 'bbands_lower'): 42.240562889112816,
#  ('obv', 'bbandwidth_100'): 65.88166214519953,
#  ('obv', 'gold_open'): 62.854369311501465,
#  ('obv', 'stoch'): 64.34866543976814,
#  ('obv', 'treasury_10_year'): 54.45265575207943,
#  ('obv', 'rsi'): 63.37185538477824,
#  ('obv', 'macd_hist'): 63.61080891805826,
#  ('bbands_lower', 'bbandwidth_100'): 41.52024219802979,
#  ('bbands_lower', 'gold_open'): 38.72928260078416,
#  ('bbands_lower', 'stoch'): 40.29918128228835,
#  ('bbands_lower', 'treasury_10_year'): 42.3761380488075,
#  ('bbands_lower', 'rsi'): 40.302427222130454,
#  ('bbands_lower', 'macd_hist'): 40.54393947373633,
#  ('bbandwidth_100', 'gold_open'): 61.746112384986326,
#  ('bbandwidth_100', 'stoch'): 72.08465999785716,
#  ('bbandwidth_100', 'treasury_10_year'): 65.9679505944712,
#  ('bbandwidth_100', 'rsi'): 74.19662193487339,
#  ('bbandwidth_100', 'macd_hist'): 64.01438181155147,
#  ('gold_open', 'stoch'): 60.56937444585635,
#  ('gold_open', 'treasury_10_year'): 57.069185507065264,
#  ('gold_open', 'rsi'): 61.31769315518156,
#  ('gold_open', 'macd_hist'): 58.4609317997072,
#  ('stoch', 'treasury_10_year'): 67.07746114193611,
#  ('stoch', 'rsi'): 77.04399464639535,
#  ('stoch', 'macd_hist'): 73.35950175626908,
#  ('treasury_10_year', 'rsi'): 72.86980438521019,
#  ('treasury_10_year', 'macd_hist'): 67.74083530067797,
#  ('rsi', 'macd_hist'): 69.86490602821131,
#  ('today_value', 'sma_100', 'bbands_upper'): 38.2753911622011,
#  ('today_value', 'sma_100', 'sma_20'): 39.03030299540994,
#  ('today_value', 'sma_100', 'obv'): 38.28216804634886,
#  ('today_value', 'sma_100', 'bbands_lower'): 38.93345042918926,
#  ('today_value', 'sma_100', 'bbandwidth_100'): 38.300132624799794,
#  ('today_value', 'sma_100', 'gold_open'): 38.43059409058877,
#  ('today_value', 'sma_100', 'stoch'): 38.54630211511567,
#  ('today_value', 'sma_100', 'treasury_10_year'): 38.43355775190285,
#  ('today_value', 'sma_100', 'rsi'): 38.33966304633558,
#  ('today_value', 'sma_100', 'macd_hist'): 38.5805912499381,
#  ('today_value', 'bbands_upper', 'sma_20'): 39.28593633173176,
#  ('today_value', 'bbands_upper', 'obv'): 37.451336156708024,
#  ('today_value', 'bbands_upper', 'bbands_lower'): 39.09110116480357,
#  ('today_value', 'bbands_upper', 'bbandwidth_100'): 37.91151831014297,
#  ('today_value', 'bbands_upper', 'gold_open'): 37.681927978054624,
#  ('today_value', 'bbands_upper', 'stoch'): 38.26295328612151,
#  ('today_value', 'bbands_upper', 'treasury_10_year'): 38.482111048303224,
#  ('today_value', 'bbands_upper', 'rsi'): 37.648460105583496,
#  ('today_value', 'bbands_upper', 'macd_hist'): 38.230846453664334,
#  ('today_value', 'sma_20', 'obv'): 39.11396977847355,
#  ('today_value', 'sma_20', 'bbands_lower'): 39.2260868335821,
#  ('today_value', 'sma_20', 'bbandwidth_100'): 39.063380365285575,
#  ('today_value', 'sma_20', 'gold_open'): 39.259975351826554,
#  ('today_value', 'sma_20', 'stoch'): 38.98563880571503,
#  ('today_value', 'sma_20', 'treasury_10_year'): 39.269114353583106,
#  ('today_value', 'sma_20', 'rsi'): 38.986434864869544,
#  ('today_value', 'sma_20', 'macd_hist'): 39.073387311957546,
#  ('today_value', 'obv', 'bbands_lower'): 39.295843320365215,
#  ('today_value', 'obv', 'bbandwidth_100'): 37.865237184349745,
#  ('today_value', 'obv', 'gold_open'): 37.77050128887692,
#  ('today_value', 'obv', 'stoch'): 38.375042154329996,
#  ('today_value', 'obv', 'treasury_10_year'): 38.18911713251445,
#  ('today_value', 'obv', 'rsi'): 37.77553039692711,
#  ('today_value', 'obv', 'macd_hist'): 38.46931092297683,
#  ('today_value', 'bbands_lower', 'bbandwidth_100'): 39.07480492412403,
#  ('today_value', 'bbands_lower', 'gold_open'): 39.22547231719464,
#  ('today_value', 'bbands_lower', 'stoch'): 38.95617138019505,
#  ('today_value', 'bbands_lower', 'treasury_10_year'): 39.32866224416528,
#  ('today_value', 'bbands_lower', 'rsi'): 38.94425201684807,
#  ('today_value', 'bbands_lower', 'macd_hist'): 39.23213472754104,
#  ('today_value', 'bbandwidth_100', 'gold_open'): 38.06076532549665,
#  ('today_value', 'bbandwidth_100', 'stoch'): 38.4023994316679,
#  ('today_value', 'bbandwidth_100', 'treasury_10_year'): 38.441141734492774,
#  ('today_value', 'bbandwidth_100', 'rsi'): 37.97134847949752,
#  ('today_value', 'bbandwidth_100', 'macd_hist'): 38.228467747561254,
#  ('today_value', 'gold_open', 'stoch'): 38.33741915434164,
#  ('today_value', 'gold_open', 'treasury_10_year'): 38.78957374616846,
#  ('today_value', 'gold_open', 'rsi'): 37.82296179678758,
#  ('today_value', 'gold_open', 'macd_hist'): 38.452768768624594,
#  ('today_value', 'stoch', 'treasury_10_year'): 38.63419614112416,
#  ('today_value', 'stoch', 'rsi'): 38.243309285096345,
#  ('today_value', 'stoch', 'macd_hist'): 38.4170644584337,
#  ('today_value', 'treasury_10_year', 'rsi'): 38.441318041794446,
#  ('today_value', 'treasury_10_year', 'macd_hist'): 38.80657294109462,
#  ('today_value', 'rsi', 'macd_hist'): 38.24322981363679,
#  ('sma_100', 'bbands_upper', 'sma_20'): 52.81892944408156,
#  ('sma_100', 'bbands_upper', 'obv'): 52.447520263762584,
#  ('sma_100', 'bbands_upper', 'bbands_lower'): 44.4944065177805,
#  ('sma_100', 'bbands_upper', 'bbandwidth_100'): 45.917197204041706,
#  ('sma_100', 'bbands_upper', 'gold_open'): 51.150173452684754,
#  ('sma_100', 'bbands_upper', 'stoch'): 53.424135390687,
#  ('sma_100', 'bbands_upper', 'treasury_10_year'): 52.46083710976966,
#  ('sma_100', 'bbands_upper', 'rsi'): 42.398863702317776,
#  ('sma_100', 'bbands_upper', 'macd_hist'): 50.753703379846044,
#  ('sma_100', 'sma_20', 'obv'): 44.05553061057439,
#  ('sma_100', 'sma_20', 'bbands_lower'): 42.65140513926726,
#  ('sma_100', 'sma_20', 'bbandwidth_100'): 43.870010307831585,
#  ('sma_100', 'sma_20', 'gold_open'): 39.3428928667883,
#  ('sma_100', 'sma_20', 'stoch'): 41.98127821858901,
#  ('sma_100', 'sma_20', 'treasury_10_year'): 42.58782205004918,
#  ('sma_100', 'sma_20', 'rsi'): 40.34599548060766,
#  ('sma_100', 'sma_20', 'macd_hist'): 43.15264631523845,
#  ('sma_100', 'obv', 'bbands_lower'): 44.10255995411077,
#  ('sma_100', 'obv', 'bbandwidth_100'): 46.280106543213186,
#  ('sma_100', 'obv', 'gold_open'): 41.76344440469173,
#  ('sma_100', 'obv', 'stoch'): 45.171129505839545,
#  ('sma_100', 'obv', 'treasury_10_year'): 44.640324283133346,
#  ('sma_100', 'obv', 'rsi'): 41.26780896678697,
#  ('sma_100', 'obv', 'macd_hist'): 45.05221690942955,
#  ('sma_100', 'bbands_lower', 'bbandwidth_100'): 43.861651194745804,
#  ('sma_100', 'bbands_lower', 'gold_open'): 39.87455564428383,
#  ('sma_100', 'bbands_lower', 'stoch'): 42.860725068792426,
#  ('sma_100', 'bbands_lower', 'treasury_10_year'): 42.8916750996216,
#  ('sma_100', 'bbands_lower', 'rsi'): 40.04412592722218,
#  ('sma_100', 'bbands_lower', 'macd_hist'): 42.85633451177772,
#  ('sma_100', 'bbandwidth_100', 'gold_open'): 45.27552535089926,
#  ('sma_100', 'bbandwidth_100', 'stoch'): 44.97187658399542,
#  ('sma_100', 'bbandwidth_100', 'treasury_10_year'): 44.57467461351523,
#  ('sma_100', 'bbandwidth_100', 'rsi'): 41.652449440842815,
#  ('sma_100', 'bbandwidth_100', 'macd_hist'): 45.038573771758514,
#  ('sma_100', 'gold_open', 'stoch'): 39.49524294283667,
#  ('sma_100', 'gold_open', 'treasury_10_year'): 39.48117501575217,
#  ('sma_100', 'gold_open', 'rsi'): 39.45244882723165,
#  ('sma_100', 'gold_open', 'macd_hist'): 39.810480697775866,
#  ('sma_100', 'stoch', 'treasury_10_year'): 41.066078756244714,
#  ('sma_100', 'stoch', 'rsi'): 40.84552654423618,
#  ('sma_100', 'stoch', 'macd_hist'): 43.59850555004566,
#  ('sma_100', 'treasury_10_year', 'rsi'): 40.33653922930391,
#  ('sma_100', 'treasury_10_year', 'macd_hist'): 42.439865063859564,
#  ('sma_100', 'rsi', 'macd_hist'): 40.98981202054423,
#  ('bbands_upper', 'sma_20', 'obv'): 52.22641443459658,
#  ('bbands_upper', 'sma_20', 'bbands_lower'): 41.76867031349924,
#  ('bbands_upper', 'sma_20', 'bbandwidth_100'): 46.104278200771724,
#  ('bbands_upper', 'sma_20', 'gold_open'): 49.5963271494433,
#  ('bbands_upper', 'sma_20', 'stoch'): 50.395381206118905,
#  ('bbands_upper', 'sma_20', 'treasury_10_year'): 50.640344061845454,
#  ('bbands_upper', 'sma_20', 'rsi'): 40.34020241700437,
#  ('bbands_upper', 'sma_20', 'macd_hist'): 40.520992399020315,
#  ('bbands_upper', 'obv', 'bbands_lower'): 43.109817788509545,
#  ('bbands_upper', 'obv', 'bbandwidth_100'): 42.991321502009384,
#  ('bbands_upper', 'obv', 'gold_open'): 66.05003004846877,
#  ('bbands_upper', 'obv', 'stoch'): 64.0178332991563,
#  ('bbands_upper', 'obv', 'treasury_10_year'): 51.11561222738799,
#  ('bbands_upper', 'obv', 'rsi'): 43.90051552518342,
#  ('bbands_upper', 'obv', 'macd_hist'): 63.11214800733397,
#  ('bbands_upper', 'bbands_lower', 'bbandwidth_100'): 41.51910632199017,
#  ('bbands_upper', 'bbands_lower', 'gold_open'): 40.4823779358843,
#  ('bbands_upper', 'bbands_lower', 'stoch'): 40.99370921983038,
#  ('bbands_upper', 'bbands_lower', 'treasury_10_year'): 44.17854794484389,
#  ('bbands_upper', 'bbands_lower', 'rsi'): 40.288249577694614,
#  ('bbands_upper', 'bbands_lower', 'macd_hist'): 40.466568161153006,
#  ('bbands_upper', 'bbandwidth_100', 'gold_open'): 41.827182934364025,
#  ('bbands_upper', 'bbandwidth_100', 'stoch'): 41.95279554061054,
#  ('bbands_upper', 'bbandwidth_100', 'treasury_10_year'): 46.030571962032056,
#  ('bbands_upper', 'bbandwidth_100', 'rsi'): 40.48917570743437,
#  ('bbands_upper', 'bbandwidth_100', 'macd_hist'): 41.28505931735896,
#  ('bbands_upper', 'gold_open', 'stoch'): 67.97426465049406,
#  ('bbands_upper', 'gold_open', 'treasury_10_year'): 55.84576157435644,
#  ('bbands_upper', 'gold_open', 'rsi'): 42.39526382412156,
#  ('bbands_upper', 'gold_open', 'macd_hist'): 66.76483417420357,
#  ('bbands_upper', 'stoch', 'treasury_10_year'): 56.8128678143956,
#  ('bbands_upper', 'stoch', 'rsi'): 43.57299605285617,
#  ('bbands_upper', 'stoch', 'macd_hist'): 66.51179456204078,
#  ('bbands_upper', 'treasury_10_year', 'rsi'): 46.47265478932993,
#  ('bbands_upper', 'treasury_10_year', 'macd_hist'): 55.593191326362266,
#  ('bbands_upper', 'rsi', 'macd_hist'): 44.225565698032014,
#  ('sma_20', 'obv', 'bbands_lower'): 41.94037212400798,
#  ('sma_20', 'obv', 'bbandwidth_100'): 42.859125050168494,
#  ('sma_20', 'obv', 'gold_open'): 40.4610688165862,
#  ('sma_20', 'obv', 'stoch'): 40.486894569173685,
#  ('sma_20', 'obv', 'treasury_10_year'): 41.70760881664886,
#  ('sma_20', 'obv', 'rsi'): 40.25048683408924,
#  ('sma_20', 'obv', 'macd_hist'): 40.80234081700205,
#  ('sma_20', 'bbands_lower', 'bbandwidth_100'): 41.84393084440332,
#  ('sma_20', 'bbands_lower', 'gold_open'): 38.81768444160154,
#  ('sma_20', 'bbands_lower', 'stoch'): 40.31515015570913,
#  ('sma_20', 'bbands_lower', 'treasury_10_year'): 41.16161505163152,
#  ('sma_20', 'bbands_lower', 'rsi'): 39.92909605374534,
#  ('sma_20', 'bbands_lower', 'macd_hist'): 40.578923878879785,
#  ('sma_20', 'bbandwidth_100', 'gold_open'): 40.41900137710965,
#  ('sma_20', 'bbandwidth_100', 'stoch'): 41.77349609370297,
#  ('sma_20', 'bbandwidth_100', 'treasury_10_year'): 42.0907208160576,
#  ('sma_20', 'bbandwidth_100', 'rsi'): 39.72222280879429,
#  ('sma_20', 'bbandwidth_100', 'macd_hist'): 41.015566038250675,
#  ('sma_20', 'gold_open', 'stoch'): 38.987708744146985,
#  ('sma_20', 'gold_open', 'treasury_10_year'): 39.729679838618715,
#  ('sma_20', 'gold_open', 'rsi'): 38.28425720700226,
#  ('sma_20', 'gold_open', 'macd_hist'): 38.981559866829265,
#  ('sma_20', 'stoch', 'treasury_10_year'): 40.149201199662556,
#  ('sma_20', 'stoch', 'rsi'): 39.85383590744851,
#  ('sma_20', 'stoch', 'macd_hist'): 40.53075656045529,
#  ('sma_20', 'treasury_10_year', 'rsi'): 40.16550491018348,
#  ('sma_20', 'treasury_10_year', 'macd_hist'): 40.719078463377244,
#  ('sma_20', 'rsi', 'macd_hist'): 39.93578966993739,
#  ('obv', 'bbands_lower', 'bbandwidth_100'): 42.26900904305355,
#  ('obv', 'bbands_lower', 'gold_open'): 41.07321983063519,
#  ('obv', 'bbands_lower', 'stoch'): 41.04025291993983,
#  ('obv', 'bbands_lower', 'treasury_10_year'): 43.39072707484213,
#  ('obv', 'bbands_lower', 'rsi'): 40.676055368415625,
#  ('obv', 'bbands_lower', 'macd_hist'): 41.05418065249431,
#  ('obv', 'bbandwidth_100', 'gold_open'): 61.31798894926914,
#  ('obv', 'bbandwidth_100', 'stoch'): 66.95736690955218,
#  ('obv', 'bbandwidth_100', 'treasury_10_year'): 60.10253493100672,
#  ('obv', 'bbandwidth_100', 'rsi'): 68.13907666420636,
#  ('obv', 'bbandwidth_100', 'macd_hist'): 63.59475285727577,
#  ('obv', 'gold_open', 'stoch'): 62.703855669773986,
#  ('obv', 'gold_open', 'treasury_10_year'): 56.268561215023,
#  ('obv', 'gold_open', 'rsi'): 62.52921205700797,
#  ('obv', 'gold_open', 'macd_hist'): 61.39840541390909,
#  ('obv', 'stoch', 'treasury_10_year'): 54.881159658554544,
#  ('obv', 'stoch', 'rsi'): 63.86644932962256,
#  ('obv', 'stoch', 'macd_hist'): 64.17560990171917,
#  ('obv', 'treasury_10_year', 'rsi'): 55.783133842531115,
#  ('obv', 'treasury_10_year', 'macd_hist'): 54.309389518080785,
#  ('obv', 'rsi', 'macd_hist'): 63.83141746429152,
#  ('bbands_lower', 'bbandwidth_100', 'gold_open'): 39.127573042923146,
#  ('bbands_lower', 'bbandwidth_100', 'stoch'): 40.50944427243073,
#  ('bbands_lower', 'bbandwidth_100', 'treasury_10_year'): 42.65926198359079,
#  ('bbands_lower', 'bbandwidth_100', 'rsi'): 40.43030462264159,
#  ('bbands_lower', 'bbandwidth_100', 'macd_hist'): 40.9076997366619,
#  ('bbands_lower', 'gold_open', 'stoch'): 38.91475432368381,
#  ('bbands_lower', 'gold_open', 'treasury_10_year'): 42.669259366375634,
#  ('bbands_lower', 'gold_open', 'rsi'): 38.52804043883645,
#  ('bbands_lower', 'gold_open', 'macd_hist'): 38.8472061324674,
#  ('bbands_lower', 'stoch', 'treasury_10_year'): 41.955501246219384,
#  ('bbands_lower', 'stoch', 'rsi'): 40.1909211936111,
#  ('bbands_lower', 'stoch', 'macd_hist'): 40.558661132104774,
#  ('bbands_lower', 'treasury_10_year', 'rsi'): 42.125479877799656,
#  ('bbands_lower', 'treasury_10_year', 'macd_hist'): 41.99516809606551,
#  ('bbands_lower', 'rsi', 'macd_hist'): 40.038078444812506,
#  ('bbandwidth_100', 'gold_open', 'stoch'): 61.32658050664425,
#  ('bbandwidth_100', 'gold_open', 'treasury_10_year'): 53.986956172527464,
#  ('bbandwidth_100', 'gold_open', 'rsi'): 61.52922719012705,
#  ('bbandwidth_100', 'gold_open', 'macd_hist'): 58.72951665242593,
#  ('bbandwidth_100', 'stoch', 'treasury_10_year'): 64.54377063940579,
#  ('bbandwidth_100', 'stoch', 'rsi'): 74.1819262203071,
#  ('bbandwidth_100', 'stoch', 'macd_hist'): 62.451532049163994,
#  ('bbandwidth_100', 'treasury_10_year', 'rsi'): 67.11811772822827,
#  ('bbandwidth_100', 'treasury_10_year', 'macd_hist'): 61.34501051275241,
#  ('bbandwidth_100', 'rsi', 'macd_hist'): 64.75567232667147,
#  ('gold_open', 'stoch', 'treasury_10_year'): 57.13223057161369,
#  ('gold_open', 'stoch', 'rsi'): 60.982708418815896,
#  ('gold_open', 'stoch', 'macd_hist'): 58.977818837066216,
#  ('gold_open', 'treasury_10_year', 'rsi'): 55.948004424359276,
#  ('gold_open', 'treasury_10_year', 'macd_hist'): 56.264811756249706,
#  ('gold_open', 'rsi', 'macd_hist'): 58.97004333952179,
#  ('stoch', 'treasury_10_year', 'rsi'): 70.71679579792867,
#  ('stoch', 'treasury_10_year', 'macd_hist'): 67.7135606062688,
#  ('stoch', 'rsi', 'macd_hist'): 70.2564043089672,
#  ('treasury_10_year', 'rsi', 'macd_hist'): 68.41382722522155,
#  ('today_value', 'sma_100', 'bbands_upper', 'sma_20'): 39.07735425136124,
#  ('today_value', 'sma_100', 'bbands_upper', 'obv'): 38.058863245935065,
#  ('today_value', 'sma_100', 'bbands_upper', 'bbands_lower'): 38.86667770387795,
#  ('today_value',
#   'sma_100',
#   'bbands_upper',
#   'bbandwidth_100'): 38.20321657605956,
#  ('today_value', 'sma_100', 'bbands_upper', 'gold_open'): 38.48366392063344,
#  ('today_value', 'sma_100', 'bbands_upper', 'stoch'): 38.283472030342814,
#  ('today_value',
#   'sma_100',
#   'bbands_upper',
#   'treasury_10_year'): 38.448401772279695,
#  ('today_value', 'sma_100', 'bbands_upper', 'rsi'): 37.99722451312263,
#  ('today_value', 'sma_100', 'bbands_upper', 'macd_hist'): 38.36723237108471,
#  ('today_value', 'sma_100', 'sma_20', 'obv'): 38.980833200352414,
#  ('today_value', 'sma_100', 'sma_20', 'bbands_lower'): 38.94994247874863,
#  ('today_value', 'sma_100', 'sma_20', 'bbandwidth_100'): 39.038131304555854,
#  ('today_value', 'sma_100', 'sma_20', 'gold_open'): 39.069391544181386,
#  ('today_value', 'sma_100', 'sma_20', 'stoch'): 38.867330052024144,
#  ('today_value', 'sma_100', 'sma_20', 'treasury_10_year'): 39.15141428953755,
#  ('today_value', 'sma_100', 'sma_20', 'rsi'): 38.867342797452,
#  ('today_value', 'sma_100', 'sma_20', 'macd_hist'): 39.1596570947732,
#  ('today_value', 'sma_100', 'obv', 'bbands_lower'): 39.03367821569753,
#  ('today_value', 'sma_100', 'obv', 'bbandwidth_100'): 38.19382286757836,
#  ('today_value', 'sma_100', 'obv', 'gold_open'): 38.30432363198159,
#  ('today_value', 'sma_100', 'obv', 'stoch'): 38.626510969704704,
#  ('today_value', 'sma_100', 'obv', 'treasury_10_year'): 38.366364902999585,
#  ('today_value', 'sma_100', 'obv', 'rsi'): 38.41768970396343,
#  ('today_value', 'sma_100', 'obv', 'macd_hist'): 38.6068269897524,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'bbandwidth_100'): 38.910657897955396,
#  ('today_value', 'sma_100', 'bbands_lower', 'gold_open'): 38.94872881142093,
#  ('today_value', 'sma_100', 'bbands_lower', 'stoch'): 38.966255373082994,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'treasury_10_year'): 39.046069291858025,
#  ('today_value', 'sma_100', 'bbands_lower', 'rsi'): 38.95221797584918,
#  ('today_value', 'sma_100', 'bbands_lower', 'macd_hist'): 39.011487235223775,
#  ('today_value', 'sma_100', 'bbandwidth_100', 'gold_open'): 38.27874800721967,
#  ('today_value', 'sma_100', 'bbandwidth_100', 'stoch'): 38.499045412493494,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.252541305963284,
#  ('today_value', 'sma_100', 'bbandwidth_100', 'rsi'): 38.25144376003149,
#  ('today_value', 'sma_100', 'bbandwidth_100', 'macd_hist'): 38.36347154222883,
#  ('today_value', 'sma_100', 'gold_open', 'stoch'): 38.45192416757286,
#  ('today_value',
#   'sma_100',
#   'gold_open',
#   'treasury_10_year'): 38.54993262997569,
#  ('today_value', 'sma_100', 'gold_open', 'rsi'): 38.19890646183271,
#  ('today_value', 'sma_100', 'gold_open', 'macd_hist'): 38.43430400595842,
#  ('today_value', 'sma_100', 'stoch', 'treasury_10_year'): 38.611387376264354,
#  ('today_value', 'sma_100', 'stoch', 'rsi'): 38.4282061149853,
#  ('today_value', 'sma_100', 'stoch', 'macd_hist'): 38.6261234287234,
#  ('today_value', 'sma_100', 'treasury_10_year', 'rsi'): 38.35721363586117,
#  ('today_value',
#   'sma_100',
#   'treasury_10_year',
#   'macd_hist'): 38.635608068230376,
#  ('today_value', 'sma_100', 'rsi', 'macd_hist'): 38.29517895548707,
#  ('today_value', 'bbands_upper', 'sma_20', 'obv'): 39.04068159535471,
#  ('today_value', 'bbands_upper', 'sma_20', 'bbands_lower'): 39.08327311696151,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbandwidth_100'): 39.07822055223606,
#  ('today_value', 'bbands_upper', 'sma_20', 'gold_open'): 39.21445988908948,
#  ('today_value', 'bbands_upper', 'sma_20', 'stoch'): 38.94150462656344,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'treasury_10_year'): 39.155062980693195,
#  ('today_value', 'bbands_upper', 'sma_20', 'rsi'): 38.908913547846126,
#  ('today_value', 'bbands_upper', 'sma_20', 'macd_hist'): 39.226106249690204,
#  ('today_value', 'bbands_upper', 'obv', 'bbands_lower'): 39.1449230412851,
#  ('today_value', 'bbands_upper', 'obv', 'bbandwidth_100'): 37.910018853603816,
#  ('today_value', 'bbands_upper', 'obv', 'gold_open'): 37.669174517281924,
#  ('today_value', 'bbands_upper', 'obv', 'stoch'): 38.37004643193298,
#  ('today_value', 'bbands_upper', 'obv', 'treasury_10_year'): 37.96704932624422,
#  ('today_value', 'bbands_upper', 'obv', 'rsi'): 37.77525575307646,
#  ('today_value', 'bbands_upper', 'obv', 'macd_hist'): 38.43625360807497,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100'): 39.00391286964323,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'gold_open'): 39.069401093081396,
#  ('today_value', 'bbands_upper', 'bbands_lower', 'stoch'): 39.01135993213639,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'treasury_10_year'): 39.12534721663181,
#  ('today_value', 'bbands_upper', 'bbands_lower', 'rsi'): 39.012765688382956,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'macd_hist'): 39.168533228694024,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'gold_open'): 38.058754610350185,
#  ('today_value', 'bbands_upper', 'bbandwidth_100', 'stoch'): 38.21233864934117,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.33277475842386,
#  ('today_value', 'bbands_upper', 'bbandwidth_100', 'rsi'): 37.96044089362699,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'macd_hist'): 38.17535142442499,
#  ('today_value', 'bbands_upper', 'gold_open', 'stoch'): 38.31077802096068,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'treasury_10_year'): 38.63885473487319,
#  ('today_value', 'bbands_upper', 'gold_open', 'rsi'): 37.94932050371385,
#  ('today_value', 'bbands_upper', 'gold_open', 'macd_hist'): 38.38689017527801,
#  ('today_value',
#   'bbands_upper',
#   'stoch',
#   'treasury_10_year'): 38.456091460874866,
#  ('today_value', 'bbands_upper', 'stoch', 'rsi'): 38.24708136046612,
#  ('today_value', 'bbands_upper', 'stoch', 'macd_hist'): 38.328754463815635,
#  ('today_value', 'bbands_upper', 'treasury_10_year', 'rsi'): 38.19941665592617,
#  ('today_value',
#   'bbands_upper',
#   'treasury_10_year',
#   'macd_hist'): 38.67151134636575,
#  ('today_value', 'bbands_upper', 'rsi', 'macd_hist'): 38.230709182874435,
#  ('today_value', 'sma_20', 'obv', 'bbands_lower'): 39.13575866348903,
#  ('today_value', 'sma_20', 'obv', 'bbandwidth_100'): 39.02589495662323,
#  ('today_value', 'sma_20', 'obv', 'gold_open'): 39.089240180126644,
#  ('today_value', 'sma_20', 'obv', 'stoch'): 38.93411755607526,
#  ('today_value', 'sma_20', 'obv', 'treasury_10_year'): 39.090499835565815,
#  ('today_value', 'sma_20', 'obv', 'rsi'): 38.82750227163765,
#  ('today_value', 'sma_20', 'obv', 'macd_hist'): 39.145122830581535,
#  ('today_value',
#   'sma_20',
#   'bbands_lower',
#   'bbandwidth_100'): 39.191201490628536,
#  ('today_value', 'sma_20', 'bbands_lower', 'gold_open'): 39.18754894815889,
#  ('today_value', 'sma_20', 'bbands_lower', 'stoch'): 39.04873833777437,
#  ('today_value',
#   'sma_20',
#   'bbands_lower',
#   'treasury_10_year'): 39.28274896362972,
#  ('today_value', 'sma_20', 'bbands_lower', 'rsi'): 39.1288465086891,
#  ('today_value', 'sma_20', 'bbands_lower', 'macd_hist'): 39.21615373010703,
#  ('today_value', 'sma_20', 'bbandwidth_100', 'gold_open'): 39.146935748130964,
#  ('today_value', 'sma_20', 'bbandwidth_100', 'stoch'): 38.94058009567079,
#  ('today_value',
#   'sma_20',
#   'bbandwidth_100',
#   'treasury_10_year'): 39.2857659098588,
#  ('today_value', 'sma_20', 'bbandwidth_100', 'rsi'): 38.83918217879987,
#  ('today_value', 'sma_20', 'bbandwidth_100', 'macd_hist'): 39.02578410797516,
#  ('today_value', 'sma_20', 'gold_open', 'stoch'): 38.927613976132086,
#  ('today_value', 'sma_20', 'gold_open', 'treasury_10_year'): 39.35869119147736,
#  ('today_value', 'sma_20', 'gold_open', 'rsi'): 38.97349753388538,
#  ('today_value', 'sma_20', 'gold_open', 'macd_hist'): 39.1242084990918,
#  ('today_value', 'sma_20', 'stoch', 'treasury_10_year'): 39.05083535822397,
#  ('today_value', 'sma_20', 'stoch', 'rsi'): 38.925659639925854,
#  ('today_value', 'sma_20', 'stoch', 'macd_hist'): 38.93611983138804,
#  ('today_value', 'sma_20', 'treasury_10_year', 'rsi'): 39.12053977176695,
#  ('today_value',
#   'sma_20',
#   'treasury_10_year',
#   'macd_hist'): 39.165418747812836,
#  ('today_value', 'sma_20', 'rsi', 'macd_hist'): 38.97797381549503,
#  ('today_value', 'obv', 'bbands_lower', 'bbandwidth_100'): 39.227801896334306,
#  ('today_value', 'obv', 'bbands_lower', 'gold_open'): 39.25141069579056,
#  ('today_value', 'obv', 'bbands_lower', 'stoch'): 39.121189102251236,
#  ('today_value',
#   'obv',
#   'bbands_lower',
#   'treasury_10_year'): 39.081366980142484,
#  ('today_value', 'obv', 'bbands_lower', 'rsi'): 39.17552033418325,
#  ('today_value', 'obv', 'bbands_lower', 'macd_hist'): 39.29547741240946,
#  ('today_value', 'obv', 'bbandwidth_100', 'gold_open'): 38.007414860676015,
#  ('today_value', 'obv', 'bbandwidth_100', 'stoch'): 38.410411299323066,
#  ('today_value',
#   'obv',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.230405870539215,
#  ('today_value', 'obv', 'bbandwidth_100', 'rsi'): 38.05340528968148,
#  ('today_value', 'obv', 'bbandwidth_100', 'macd_hist'): 38.440476712833245,
#  ('today_value', 'obv', 'gold_open', 'stoch'): 38.391023984306855,
#  ('today_value', 'obv', 'gold_open', 'treasury_10_year'): 38.46790749320311,
#  ('today_value', 'obv', 'gold_open', 'rsi'): 37.88945963830153,
#  ('today_value', 'obv', 'gold_open', 'macd_hist'): 38.458904601469115,
#  ('today_value', 'obv', 'stoch', 'treasury_10_year'): 38.532117688392255,
#  ('today_value', 'obv', 'stoch', 'rsi'): 38.49270455273586,
#  ('today_value', 'obv', 'stoch', 'macd_hist'): 38.491380880762335,
#  ('today_value', 'obv', 'treasury_10_year', 'rsi'): 38.360935909211264,
#  ('today_value', 'obv', 'treasury_10_year', 'macd_hist'): 38.52716388286821,
#  ('today_value', 'obv', 'rsi', 'macd_hist'): 38.481578387318756,
#  ('today_value',
#   'bbands_lower',
#   'bbandwidth_100',
#   'gold_open'): 39.20970727374602,
#  ('today_value', 'bbands_lower', 'bbandwidth_100', 'stoch'): 39.0596274658708,
#  ('today_value',
#   'bbands_lower',
#   'bbandwidth_100',
#   'treasury_10_year'): 39.25381972408742,
#  ('today_value', 'bbands_lower', 'bbandwidth_100', 'rsi'): 39.15894274736565,
#  ('today_value',
#   'bbands_lower',
#   'bbandwidth_100',
#   'macd_hist'): 39.232962253716124,
#  ('today_value', 'bbands_lower', 'gold_open', 'stoch'): 39.02475951748021,
#  ('today_value',
#   'bbands_lower',
#   'gold_open',
#   'treasury_10_year'): 39.36411086240972,
#  ('today_value', 'bbands_lower', 'gold_open', 'rsi'): 39.21576437224734,
#  ('today_value', 'bbands_lower', 'gold_open', 'macd_hist'): 39.24148342426613,
#  ('today_value',
#   'bbands_lower',
#   'stoch',
#   'treasury_10_year'): 39.011861921725924,
#  ('today_value', 'bbands_lower', 'stoch', 'rsi'): 38.844046516034076,
#  ('today_value', 'bbands_lower', 'stoch', 'macd_hist'): 39.07473075033502,
#  ('today_value',
#   'bbands_lower',
#   'treasury_10_year',
#   'rsi'): 39.247251070552736,
#  ('today_value',
#   'bbands_lower',
#   'treasury_10_year',
#   'macd_hist'): 39.30134465325007,
#  ('today_value', 'bbands_lower', 'rsi', 'macd_hist'): 39.185108096423576,
#  ('today_value', 'bbandwidth_100', 'gold_open', 'stoch'): 38.30638822606548,
#  ('today_value',
#   'bbandwidth_100',
#   'gold_open',
#   'treasury_10_year'): 38.48790168967171,
#  ('today_value', 'bbandwidth_100', 'gold_open', 'rsi'): 38.04036845496191,
#  ('today_value',
#   'bbandwidth_100',
#   'gold_open',
#   'macd_hist'): 38.25580830933507,
#  ('today_value',
#   'bbandwidth_100',
#   'stoch',
#   'treasury_10_year'): 38.571642318693726,
#  ('today_value', 'bbandwidth_100', 'stoch', 'rsi'): 38.28566390713736,
#  ('today_value', 'bbandwidth_100', 'stoch', 'macd_hist'): 38.39624155362327,
#  ('today_value',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'rsi'): 38.413370255129614,
#  ('today_value',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'macd_hist'): 38.57640681918498,
#  ('today_value', 'bbandwidth_100', 'rsi', 'macd_hist'): 38.22695952499899,
#  ('today_value', 'gold_open', 'stoch', 'treasury_10_year'): 38.745109233883966,
#  ('today_value', 'gold_open', 'stoch', 'rsi'): 38.37704127094324,
#  ('today_value', 'gold_open', 'stoch', 'macd_hist'): 38.49701297653562,
#  ('today_value', 'gold_open', 'treasury_10_year', 'rsi'): 38.463656026288106,
#  ('today_value',
#   'gold_open',
#   'treasury_10_year',
#   'macd_hist'): 38.79914871099557,
#  ('today_value', 'gold_open', 'rsi', 'macd_hist'): 38.34454986803062,
#  ('today_value', 'stoch', 'treasury_10_year', 'rsi'): 38.51584372792125,
#  ('today_value', 'stoch', 'treasury_10_year', 'macd_hist'): 38.7488426831824,
#  ('today_value', 'stoch', 'rsi', 'macd_hist'): 38.34214054872629,
#  ('today_value', 'treasury_10_year', 'rsi', 'macd_hist'): 38.65441247765385,
#  ('sma_100', 'bbands_upper', 'sma_20', 'obv'): 52.64077297589018,
#  ('sma_100', 'bbands_upper', 'sma_20', 'bbands_lower'): 43.662058424638374,
#  ('sma_100', 'bbands_upper', 'sma_20', 'bbandwidth_100'): 47.55669205949299,
#  ('sma_100', 'bbands_upper', 'sma_20', 'gold_open'): 49.79856714060533,
#  ('sma_100', 'bbands_upper', 'sma_20', 'stoch'): 51.48930811899247,
#  ('sma_100', 'bbands_upper', 'sma_20', 'treasury_10_year'): 52.118688047042845,
#  ('sma_100', 'bbands_upper', 'sma_20', 'rsi'): 40.176279137535026,
#  ('sma_100', 'bbands_upper', 'sma_20', 'macd_hist'): 43.1518449089563,
#  ('sma_100', 'bbands_upper', 'obv', 'bbands_lower'): 44.140317422376995,
#  ('sma_100', 'bbands_upper', 'obv', 'bbandwidth_100'): 45.106891728486524,
#  ('sma_100', 'bbands_upper', 'obv', 'gold_open'): 52.082226030718275,
#  ('sma_100', 'bbands_upper', 'obv', 'stoch'): 52.758231379464554,
#  ('sma_100', 'bbands_upper', 'obv', 'treasury_10_year'): 51.445503033965736,
#  ('sma_100', 'bbands_upper', 'obv', 'rsi'): 42.345997608652176,
#  ('sma_100', 'bbands_upper', 'obv', 'macd_hist'): 50.99951286006384,
#  ('sma_100',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100'): 44.238720016662306,
#  ('sma_100', 'bbands_upper', 'bbands_lower', 'gold_open'): 41.26611924916306,
#  ('sma_100', 'bbands_upper', 'bbands_lower', 'stoch'): 43.97708449453014,
#  ('sma_100',
#   'bbands_upper',
#   'bbands_lower',
#   'treasury_10_year'): 43.76234852573025,
#  ('sma_100', 'bbands_upper', 'bbands_lower', 'rsi'): 39.771697522804196,
#  ('sma_100', 'bbands_upper', 'bbands_lower', 'macd_hist'): 42.16028979841422,
#  ('sma_100',
#   'bbands_upper',
#   'bbandwidth_100',
#   'gold_open'): 43.193202754990324,
#  ('sma_100', 'bbands_upper', 'bbandwidth_100', 'stoch'): 44.40425333421018,
#  ('sma_100',
#   'bbands_upper',
#   'bbandwidth_100',
#   'treasury_10_year'): 44.93611866796324,
#  ('sma_100', 'bbands_upper', 'bbandwidth_100', 'rsi'): 40.42313788612794,
#  ('sma_100',
#   'bbands_upper',
#   'bbandwidth_100',
#   'macd_hist'): 42.221485318575475,
#  ('sma_100', 'bbands_upper', 'gold_open', 'stoch'): 50.878252575167586,
#  ('sma_100',
#   'bbands_upper',
#   'gold_open',
#   'treasury_10_year'): 50.1103861941904,
#  ('sma_100', 'bbands_upper', 'gold_open', 'rsi'): 40.90596015972998,
#  ('sma_100', 'bbands_upper', 'gold_open', 'macd_hist'): 49.06936899807398,
#  ('sma_100', 'bbands_upper', 'stoch', 'treasury_10_year'): 52.240637082038845,
#  ('sma_100', 'bbands_upper', 'stoch', 'rsi'): 42.38442857876401,
#  ('sma_100', 'bbands_upper', 'stoch', 'macd_hist'): 50.449890372904136,
#  ('sma_100', 'bbands_upper', 'treasury_10_year', 'rsi'): 42.08397166455057,
#  ('sma_100',
#   'bbands_upper',
#   'treasury_10_year',
#   'macd_hist'): 50.57319453873234,
#  ('sma_100', 'bbands_upper', 'rsi', 'macd_hist'): 42.49114612336752,
#  ('sma_100', 'sma_20', 'obv', 'bbands_lower'): 43.52284952458002,
#  ('sma_100', 'sma_20', 'obv', 'bbandwidth_100'): 44.770768684956764,
#  ('sma_100', 'sma_20', 'obv', 'gold_open'): 39.6788722586107,
#  ('sma_100', 'sma_20', 'obv', 'stoch'): 42.66392222911753,
#  ('sma_100', 'sma_20', 'obv', 'treasury_10_year'): 43.198908389965915,
#  ('sma_100', 'sma_20', 'obv', 'rsi'): 40.44252087835281,
#  ('sma_100', 'sma_20', 'obv', 'macd_hist'): 42.80507170524163,
#  ('sma_100', 'sma_20', 'bbands_lower', 'bbandwidth_100'): 43.183128091144894,
#  ('sma_100', 'sma_20', 'bbands_lower', 'gold_open'): 40.097898265470725,
#  ('sma_100', 'sma_20', 'bbands_lower', 'stoch'): 42.2566428188194,
#  ('sma_100', 'sma_20', 'bbands_lower', 'treasury_10_year'): 42.60722340480329,
#  ('sma_100', 'sma_20', 'bbands_lower', 'rsi'): 40.15022056623448,
#  ('sma_100', 'sma_20', 'bbands_lower', 'macd_hist'): 42.746552032351985,
#  ('sma_100', 'sma_20', 'bbandwidth_100', 'gold_open'): 41.09099277987628,
#  ('sma_100', 'sma_20', 'bbandwidth_100', 'stoch'): 43.21126775605981,
#  ('sma_100',
#   'sma_20',
#   'bbandwidth_100',
#   'treasury_10_year'): 43.94164672660616,
#  ('sma_100', 'sma_20', 'bbandwidth_100', 'rsi'): 40.310272431235305,
#  ('sma_100', 'sma_20', 'bbandwidth_100', 'macd_hist'): 42.55863996799397,
#  ('sma_100', 'sma_20', 'gold_open', 'stoch'): 39.72012997380588,
#  ('sma_100', 'sma_20', 'gold_open', 'treasury_10_year'): 40.317571699232126,
#  ('sma_100', 'sma_20', 'gold_open', 'rsi'): 38.93089990321173,
#  ('sma_100', 'sma_20', 'gold_open', 'macd_hist'): 39.90178045724346,
#  ('sma_100', 'sma_20', 'stoch', 'treasury_10_year'): 42.13440661738797,
#  ('sma_100', 'sma_20', 'stoch', 'rsi'): 40.411467659730796,
#  ('sma_100', 'sma_20', 'stoch', 'macd_hist'): 42.93559756856183,
#  ('sma_100', 'sma_20', 'treasury_10_year', 'rsi'): 40.351713495728404,
#  ('sma_100', 'sma_20', 'treasury_10_year', 'macd_hist'): 42.702977213179935,
#  ('sma_100', 'sma_20', 'rsi', 'macd_hist'): 40.545419819318624,
#  ('sma_100', 'obv', 'bbands_lower', 'bbandwidth_100'): 44.33385463932061,
#  ('sma_100', 'obv', 'bbands_lower', 'gold_open'): 40.2741746170793,
#  ('sma_100', 'obv', 'bbands_lower', 'stoch'): 42.88922775253922,
#  ('sma_100', 'obv', 'bbands_lower', 'treasury_10_year'): 43.443864592544436,
#  ('sma_100', 'obv', 'bbands_lower', 'rsi'): 40.27789731722444,
#  ('sma_100', 'obv', 'bbands_lower', 'macd_hist'): 42.40818677826083,
#  ('sma_100', 'obv', 'bbandwidth_100', 'gold_open'): 44.65788692231881,
#  ('sma_100', 'obv', 'bbandwidth_100', 'stoch'): 45.31737742542109,
#  ('sma_100', 'obv', 'bbandwidth_100', 'treasury_10_year'): 45.51329079549817,
#  ('sma_100', 'obv', 'bbandwidth_100', 'rsi'): 42.04696449341042,
#  ('sma_100', 'obv', 'bbandwidth_100', 'macd_hist'): 45.07604428061226,
#  ('sma_100', 'obv', 'gold_open', 'stoch'): 41.83203203100977,
#  ('sma_100', 'obv', 'gold_open', 'treasury_10_year'): 42.26738261010991,
#  ('sma_100', 'obv', 'gold_open', 'rsi'): 40.8087702054184,
#  ('sma_100', 'obv', 'gold_open', 'macd_hist'): 42.13266526418467,
#  ('sma_100', 'obv', 'stoch', 'treasury_10_year'): 43.75648878166857,
#  ('sma_100', 'obv', 'stoch', 'rsi'): 41.42932569876406,
#  ('sma_100', 'obv', 'stoch', 'macd_hist'): 43.81490770689423,
#  ('sma_100', 'obv', 'treasury_10_year', 'rsi'): 41.47996634338031,
#  ('sma_100', 'obv', 'treasury_10_year', 'macd_hist'): 43.84180229190968,
#  ('sma_100', 'obv', 'rsi', 'macd_hist'): 41.16777563898899,
#  ('sma_100', 'bbands_lower', 'bbandwidth_100', 'gold_open'): 40.33547848616076,
#  ('sma_100', 'bbands_lower', 'bbandwidth_100', 'stoch'): 43.15260193511737,
#  ('sma_100',
#   'bbands_lower',
#   'bbandwidth_100',
#   'treasury_10_year'): 43.18178367828794,
#  ('sma_100', 'bbands_lower', 'bbandwidth_100', 'rsi'): 39.88952775257366,
#  ('sma_100', 'bbands_lower', 'bbandwidth_100', 'macd_hist'): 42.53242500451442,
#  ('sma_100', 'bbands_lower', 'gold_open', 'stoch'): 40.049406891884125,
#  ('sma_100',
#   'bbands_lower',
#   'gold_open',
#   'treasury_10_year'): 40.5031109420487,
#  ('sma_100', 'bbands_lower', 'gold_open', 'rsi'): 38.93587894671793,
#  ('sma_100', 'bbands_lower', 'gold_open', 'macd_hist'): 39.719819083826316,
#  ('sma_100', 'bbands_lower', 'stoch', 'treasury_10_year'): 42.329668797278416,
#  ('sma_100', 'bbands_lower', 'stoch', 'rsi'): 40.17376501605681,
#  ('sma_100', 'bbands_lower', 'stoch', 'macd_hist'): 42.78092417279103,
#  ('sma_100', 'bbands_lower', 'treasury_10_year', 'rsi'): 40.194473298541105,
#  ('sma_100',
#   'bbands_lower',
#   'treasury_10_year',
#   'macd_hist'): 42.557090121247526,
#  ('sma_100', 'bbands_lower', 'rsi', 'macd_hist'): 40.33100633580043,
#  ('sma_100', 'bbandwidth_100', 'gold_open', 'stoch'): 43.58839354683388,
#  ('sma_100',
#   'bbandwidth_100',
#   'gold_open',
#   'treasury_10_year'): 44.525650796119834,
#  ('sma_100', 'bbandwidth_100', 'gold_open', 'rsi'): 40.30437016141859,
#  ('sma_100', 'bbandwidth_100', 'gold_open', 'macd_hist'): 44.15317550597819,
#  ('sma_100',
#   'bbandwidth_100',
#   'stoch',
#   'treasury_10_year'): 43.903974243466266,
#  ('sma_100', 'bbandwidth_100', 'stoch', 'rsi'): 41.86140089560522,
#  ('sma_100', 'bbandwidth_100', 'stoch', 'macd_hist'): 44.6947464949651,
#  ('sma_100', 'bbandwidth_100', 'treasury_10_year', 'rsi'): 41.336032198984725,
#  ('sma_100',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'macd_hist'): 43.97970865020631,
#  ('sma_100', 'bbandwidth_100', 'rsi', 'macd_hist'): 41.54888582265336,
#  ('sma_100', 'gold_open', 'stoch', 'treasury_10_year'): 39.79115954511967,
#  ('sma_100', 'gold_open', 'stoch', 'rsi'): 39.683225419719754,
#  ('sma_100', 'gold_open', 'stoch', 'macd_hist'): 41.017744230091694,
#  ('sma_100', 'gold_open', 'treasury_10_year', 'rsi'): 39.998618699943,
#  ('sma_100', 'gold_open', 'treasury_10_year', 'macd_hist'): 40.486565507974,
#  ('sma_100', 'gold_open', 'rsi', 'macd_hist'): 40.36677190983182,
#  ('sma_100', 'stoch', 'treasury_10_year', 'rsi'): 40.57868447783886,
#  ('sma_100', 'stoch', 'treasury_10_year', 'macd_hist'): 42.39510768781123,
#  ('sma_100', 'stoch', 'rsi', 'macd_hist'): 41.13665634552266,
#  ('sma_100', 'treasury_10_year', 'rsi', 'macd_hist'): 40.69354903399318,
#  ('bbands_upper', 'sma_20', 'obv', 'bbands_lower'): 42.84515229517171,
#  ('bbands_upper', 'sma_20', 'obv', 'bbandwidth_100'): 46.99575796136949,
#  ('bbands_upper', 'sma_20', 'obv', 'gold_open'): 49.54365198545685,
#  ('bbands_upper', 'sma_20', 'obv', 'stoch'): 50.548157818492186,
#  ('bbands_upper', 'sma_20', 'obv', 'treasury_10_year'): 50.522821347336944,
#  ('bbands_upper', 'sma_20', 'obv', 'rsi'): 40.84322854632166,
#  ('bbands_upper', 'sma_20', 'obv', 'macd_hist'): 41.792487448431004,
#  ('bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'bbandwidth_100'): 42.07653565072349,
#  ('bbands_upper', 'sma_20', 'bbands_lower', 'gold_open'): 39.957547735845985,
#  ('bbands_upper', 'sma_20', 'bbands_lower', 'stoch'): 40.826596563552314,
#  ('bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'treasury_10_year'): 42.61111076672303,
#  ('bbands_upper', 'sma_20', 'bbands_lower', 'rsi'): 40.05542108883461,
#  ('bbands_upper', 'sma_20', 'bbands_lower', 'macd_hist'): 40.621744011950625,
#  ('bbands_upper', 'sma_20', 'bbandwidth_100', 'gold_open'): 43.84339945773884,
#  ('bbands_upper', 'sma_20', 'bbandwidth_100', 'stoch'): 44.93869287732643,
#  ('bbands_upper',
#   'sma_20',
#   'bbandwidth_100',
#   'treasury_10_year'): 45.7252790431932,
#  ('bbands_upper', 'sma_20', 'bbandwidth_100', 'rsi'): 40.104733749624216,
#  ('bbands_upper', 'sma_20', 'bbandwidth_100', 'macd_hist'): 41.27278627563781,
#  ('bbands_upper', 'sma_20', 'gold_open', 'stoch'): 49.427066534698,
#  ('bbands_upper',
#   'sma_20',
#   'gold_open',
#   'treasury_10_year'): 48.98871082723221,
#  ('bbands_upper', 'sma_20', 'gold_open', 'rsi'): 39.1207576465503,
#  ('bbands_upper', 'sma_20', 'gold_open', 'macd_hist'): 40.01914560336034,
#  ('bbands_upper', 'sma_20', 'stoch', 'treasury_10_year'): 49.55315017634274,
#  ('bbands_upper', 'sma_20', 'stoch', 'rsi'): 40.16846610546243,
#  ('bbands_upper', 'sma_20', 'stoch', 'macd_hist'): 40.94228986918506,
#  ('bbands_upper', 'sma_20', 'treasury_10_year', 'rsi'): 40.4823589030353,
#  ('bbands_upper',
#   'sma_20',
#   'treasury_10_year',
#   'macd_hist'): 41.88729504946087,
#  ('bbands_upper', 'sma_20', 'rsi', 'macd_hist'): 40.36750606274825,
#  ('bbands_upper', 'obv', 'bbands_lower', 'bbandwidth_100'): 42.79000552288433,
#  ('bbands_upper', 'obv', 'bbands_lower', 'gold_open'): 41.89322357678438,
#  ('bbands_upper', 'obv', 'bbands_lower', 'stoch'): 42.059834329654024,
#  ('bbands_upper',
#   'obv',
#   'bbands_lower',
#   'treasury_10_year'): 45.71364224712321,
#  ('bbands_upper', 'obv', 'bbands_lower', 'rsi'): 40.52315517746042,
#  ('bbands_upper', 'obv', 'bbands_lower', 'macd_hist'): 40.9909020249009,
#  ('bbands_upper', 'obv', 'bbandwidth_100', 'gold_open'): 41.66964115003396,
#  ('bbands_upper', 'obv', 'bbandwidth_100', 'stoch'): 42.15616277065196,
#  ('bbands_upper',
#   'obv',
#   'bbandwidth_100',
#   'treasury_10_year'): 45.48182075162607,
#  ('bbands_upper', 'obv', 'bbandwidth_100', 'rsi'): 40.98367065445014,
#  ('bbands_upper', 'obv', 'bbandwidth_100', 'macd_hist'): 41.75012578713526,
#  ('bbands_upper', 'obv', 'gold_open', 'stoch'): 66.16579754932191,
#  ('bbands_upper', 'obv', 'gold_open', 'treasury_10_year'): 51.56150901721247,
#  ('bbands_upper', 'obv', 'gold_open', 'rsi'): 43.11299272486001,
#  ('bbands_upper', 'obv', 'gold_open', 'macd_hist'): 65.26346432337154,
#  ('bbands_upper', 'obv', 'stoch', 'treasury_10_year'): 51.56909627490243,
#  ('bbands_upper', 'obv', 'stoch', 'rsi'): 43.6276862936111,
#  ('bbands_upper', 'obv', 'stoch', 'macd_hist'): 63.2251445917504,
#  ('bbands_upper', 'obv', 'treasury_10_year', 'rsi'): 45.53036052007154,
#  ('bbands_upper', 'obv', 'treasury_10_year', 'macd_hist'): 51.561232891050594,
#  ('bbands_upper', 'obv', 'rsi', 'macd_hist'): 44.11898883428433,
#  ('bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'gold_open'): 39.72102835546541,
#  ('bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'stoch'): 40.740611980398526,
#  ('bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'treasury_10_year'): 44.20428074950498,
#  ('bbands_upper', 'bbands_lower', 'bbandwidth_100', 'rsi'): 40.424235572045376,
#  ('bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'macd_hist'): 40.68924936618247,
#  ('bbands_upper', 'bbands_lower', 'gold_open', 'stoch'): 40.25231809411178,
#  ('bbands_upper',
#   'bbands_lower',
#   'gold_open',
#   'treasury_10_year'): 43.81451561496167,
#  ('bbands_upper', 'bbands_lower', 'gold_open', 'rsi'): 38.76886517558408,
#  ('bbands_upper', 'bbands_lower', 'gold_open', 'macd_hist'): 39.35398997583386,
#  ('bbands_upper',
#   'bbands_lower',
#   'stoch',
#   'treasury_10_year'): 44.036465711772586,
#  ('bbands_upper', 'bbands_lower', 'stoch', 'rsi'): 39.69281217864487,
#  ('bbands_upper', 'bbands_lower', 'stoch', 'macd_hist'): 40.271911243498366,
#  ('bbands_upper',
#   'bbands_lower',
#   'treasury_10_year',
#   'rsi'): 43.007934204044744,
#  ('bbands_upper',
#   'bbands_lower',
#   'treasury_10_year',
#   'macd_hist'): 43.343523164003535,
#  ('bbands_upper', 'bbands_lower', 'rsi', 'macd_hist'): 40.30528671765998,
#  ('bbands_upper', 'bbandwidth_100', 'gold_open', 'stoch'): 41.26149503668379,
#  ('bbands_upper',
#   'bbandwidth_100',
#   'gold_open',
#   'treasury_10_year'): 45.27823865760911,
#  ('bbands_upper', 'bbandwidth_100', 'gold_open', 'rsi'): 40.17455910739807,
#  ('bbands_upper',
#   'bbandwidth_100',
#   'gold_open',
#   'macd_hist'): 40.59253964175898,
#  ('bbands_upper',
#   'bbandwidth_100',
#   'stoch',
#   'treasury_10_year'): 45.66742665533406,
#  ('bbands_upper', 'bbandwidth_100', 'stoch', 'rsi'): 40.809654254742355,
#  ('bbands_upper', 'bbandwidth_100', 'stoch', 'macd_hist'): 41.04279008854283,
#  ('bbands_upper',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'rsi'): 44.439464956699865,
#  ('bbands_upper',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'macd_hist'): 45.41677070368841,
#  ('bbands_upper', 'bbandwidth_100', 'rsi', 'macd_hist'): 41.158287542942574,
#  ('bbands_upper', 'gold_open', 'stoch', 'treasury_10_year'): 55.85644838352592,
#  ('bbands_upper', 'gold_open', 'stoch', 'rsi'): 42.25480858079552,
#  ('bbands_upper', 'gold_open', 'stoch', 'macd_hist'): 66.56277563804954,
#  ('bbands_upper', 'gold_open', 'treasury_10_year', 'rsi'): 46.25003095113863,
#  ('bbands_upper',
#   'gold_open',
#   'treasury_10_year',
#   'macd_hist'): 55.01552921882283,
#  ('bbands_upper', 'gold_open', 'rsi', 'macd_hist'): 42.679576494864854,
#  ('bbands_upper', 'stoch', 'treasury_10_year', 'rsi'): 46.56136024239838,
#  ('bbands_upper',
#   'stoch',
#   'treasury_10_year',
#   'macd_hist'): 55.323504951264596,
#  ('bbands_upper', 'stoch', 'rsi', 'macd_hist'): 44.24033369782628,
#  ('bbands_upper', 'treasury_10_year', 'rsi', 'macd_hist'): 46.8648725547152,
#  ('sma_20', 'obv', 'bbands_lower', 'bbandwidth_100'): 42.22944920936521,
#  ('sma_20', 'obv', 'bbands_lower', 'gold_open'): 40.474861785385464,
#  ('sma_20', 'obv', 'bbands_lower', 'stoch'): 40.69678519052196,
#  ('sma_20', 'obv', 'bbands_lower', 'treasury_10_year'): 41.615277372779545,
#  ('sma_20', 'obv', 'bbands_lower', 'rsi'): 40.426011102190635,
#  ('sma_20', 'obv', 'bbands_lower', 'macd_hist'): 40.81261506873117,
#  ('sma_20', 'obv', 'bbandwidth_100', 'gold_open'): 41.02988759765066,
#  ('sma_20', 'obv', 'bbandwidth_100', 'stoch'): 42.06590381527377,
#  ('sma_20', 'obv', 'bbandwidth_100', 'treasury_10_year'): 42.511547701175175,
#  ('sma_20', 'obv', 'bbandwidth_100', 'rsi'): 40.399796546123504,
#  ('sma_20', 'obv', 'bbandwidth_100', 'macd_hist'): 41.09758985997422,
#  ('sma_20', 'obv', 'gold_open', 'stoch'): 39.56727987218613,
#  ('sma_20', 'obv', 'gold_open', 'treasury_10_year'): 40.35157742253383,
#  ('sma_20', 'obv', 'gold_open', 'rsi'): 39.61743327394784,
#  ('sma_20', 'obv', 'gold_open', 'macd_hist'): 39.65898867671949,
#  ('sma_20', 'obv', 'stoch', 'treasury_10_year'): 40.554825515361195,
#  ('sma_20', 'obv', 'stoch', 'rsi'): 40.17646008665711,
#  ('sma_20', 'obv', 'stoch', 'macd_hist'): 40.83677990191746,
#  ('sma_20', 'obv', 'treasury_10_year', 'rsi'): 40.58472649265335,
#  ('sma_20', 'obv', 'treasury_10_year', 'macd_hist'): 40.810557569678146,
#  ('sma_20', 'obv', 'rsi', 'macd_hist'): 40.314659874980705,
#  ('sma_20', 'bbands_lower', 'bbandwidth_100', 'gold_open'): 39.69121897511866,
#  ('sma_20', 'bbands_lower', 'bbandwidth_100', 'stoch'): 40.992142698819904,
#  ('sma_20',
#   'bbands_lower',
#   'bbandwidth_100',
#   'treasury_10_year'): 41.580755737020716,
#  ('sma_20', 'bbands_lower', 'bbandwidth_100', 'rsi'): 39.96671871022772,
#  ('sma_20', 'bbands_lower', 'bbandwidth_100', 'macd_hist'): 40.90157413789732,
#  ('sma_20', 'bbands_lower', 'gold_open', 'stoch'): 38.81236209827035,
#  ('sma_20',
#   'bbands_lower',
#   'gold_open',
#   'treasury_10_year'): 39.32338373734657,
#  ('sma_20', 'bbands_lower', 'gold_open', 'rsi'): 38.79391858251476,
#  ('sma_20', 'bbands_lower', 'gold_open', 'macd_hist'): 39.04049973328271,
#  ('sma_20', 'bbands_lower', 'stoch', 'treasury_10_year'): 40.19470417345465,
#  ('sma_20', 'bbands_lower', 'stoch', 'rsi'): 39.949374650010945,
#  ('sma_20', 'bbands_lower', 'stoch', 'macd_hist'): 40.55692379800156,
#  ('sma_20', 'bbands_lower', 'treasury_10_year', 'rsi'): 40.07080598288191,
#  ('sma_20',
#   'bbands_lower',
#   'treasury_10_year',
#   'macd_hist'): 40.776333952138906,
#  ('sma_20', 'bbands_lower', 'rsi', 'macd_hist'): 39.95866250305417,
#  ('sma_20', 'bbandwidth_100', 'gold_open', 'stoch'): 40.34834563764075,
#  ('sma_20',
#   'bbandwidth_100',
#   'gold_open',
#   'treasury_10_year'): 40.86475040874538,
#  ('sma_20', 'bbandwidth_100', 'gold_open', 'rsi'): 38.76432951578324,
#  ('sma_20', 'bbandwidth_100', 'gold_open', 'macd_hist'): 39.32867010692606,
#  ('sma_20', 'bbandwidth_100', 'stoch', 'treasury_10_year'): 41.52090182151854,
#  ('sma_20', 'bbandwidth_100', 'stoch', 'rsi'): 39.898031735513186,
#  ('sma_20', 'bbandwidth_100', 'stoch', 'macd_hist'): 40.994756729654846,
# ...
#  ('today_value', 'sma_100', 'sma_20', 'obv', 'stoch'): 39.02725985031914,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'obv',
#   'treasury_10_year'): 38.99255411223989,
#  ('today_value', 'sma_100', 'sma_20', 'obv', 'rsi'): 38.90458089747841,
#  ('today_value', 'sma_100', 'sma_20', 'obv', 'macd_hist'): 39.01990088714628,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbands_lower',
#   'bbandwidth_100'): 38.996050528047036,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbands_lower',
#   'gold_open'): 38.95345916133738,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbands_lower',
#   'stoch'): 38.8768669519779,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbands_lower',
#   'treasury_10_year'): 39.065426860808586,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbands_lower',
#   'rsi'): 38.91819246699008,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbands_lower',
#   'macd_hist'): 39.124959765092214,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbandwidth_100',
#   'gold_open'): 38.93039315212213,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbandwidth_100',
#   'stoch'): 38.76372598883712,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.978565537301364,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbandwidth_100',
#   'rsi'): 38.78067372449891,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'bbandwidth_100',
#   'macd_hist'): 38.95957368071888,
#  ('today_value', 'sma_100', 'sma_20', 'gold_open', 'stoch'): 38.77709706015709,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'gold_open',
#   'treasury_10_year'): 39.29334910323285,
#  ('today_value', 'sma_100', 'sma_20', 'gold_open', 'rsi'): 39.000986848342194,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'gold_open',
#   'macd_hist'): 38.963362587441864,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'stoch',
#   'treasury_10_year'): 38.90056993254281,
#  ('today_value', 'sma_100', 'sma_20', 'stoch', 'rsi'): 38.77183420545016,
#  ('today_value', 'sma_100', 'sma_20', 'stoch', 'macd_hist'): 38.78249331633794,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'treasury_10_year',
#   'rsi'): 38.928061190603884,
#  ('today_value',
#   'sma_100',
#   'sma_20',
#   'treasury_10_year',
#   'macd_hist'): 39.032182120052035,
#  ('today_value', 'sma_100', 'sma_20', 'rsi', 'macd_hist'): 38.938438349336344,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbands_lower',
#   'bbandwidth_100'): 39.01975975689501,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbands_lower',
#   'gold_open'): 39.00909838587427,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbands_lower',
#   'stoch'): 39.038723781078964,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbands_lower',
#   'treasury_10_year'): 39.06184315834397,
#  ('today_value', 'sma_100', 'obv', 'bbands_lower', 'rsi'): 38.97933220942202,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbands_lower',
#   'macd_hist'): 39.18269993124194,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbandwidth_100',
#   'gold_open'): 38.294942660998146,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbandwidth_100',
#   'stoch'): 38.50545924832504,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.4949340762381,
#  ('today_value', 'sma_100', 'obv', 'bbandwidth_100', 'rsi'): 38.36489660426618,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'bbandwidth_100',
#   'macd_hist'): 38.54858344651254,
#  ('today_value', 'sma_100', 'obv', 'gold_open', 'stoch'): 38.49711342401796,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'gold_open',
#   'treasury_10_year'): 38.52506010584108,
#  ('today_value', 'sma_100', 'obv', 'gold_open', 'rsi'): 38.20650463046473,
#  ('today_value', 'sma_100', 'obv', 'gold_open', 'macd_hist'): 38.5694110136466,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'stoch',
#   'treasury_10_year'): 38.72095653251609,
#  ('today_value', 'sma_100', 'obv', 'stoch', 'rsi'): 38.501825413837366,
#  ('today_value', 'sma_100', 'obv', 'stoch', 'macd_hist'): 38.677962104839,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'treasury_10_year',
#   'rsi'): 38.30273479967956,
#  ('today_value',
#   'sma_100',
#   'obv',
#   'treasury_10_year',
#   'macd_hist'): 38.634180952336095,
#  ('today_value', 'sma_100', 'obv', 'rsi', 'macd_hist'): 38.467176071660155,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'bbandwidth_100',
#   'gold_open'): 38.92921210094512,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'bbandwidth_100',
#   'stoch'): 38.80329851787089,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.96416816140193,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'bbandwidth_100',
#   'rsi'): 38.84568945845699,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'bbandwidth_100',
#   'macd_hist'): 38.997244997696036,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'gold_open',
#   'stoch'): 38.990325315328604,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'gold_open',
#   'treasury_10_year'): 39.08123473300398,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'gold_open',
#   'rsi'): 38.88712339999111,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'gold_open',
#   'macd_hist'): 39.016336260674684,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'stoch',
#   'treasury_10_year'): 38.968445720784445,
#  ('today_value', 'sma_100', 'bbands_lower', 'stoch', 'rsi'): 38.80067012179306,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'stoch',
#   'macd_hist'): 38.89510814568309,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'treasury_10_year',
#   'rsi'): 39.03150581853234,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'treasury_10_year',
#   'macd_hist'): 39.06498136411539,
#  ('today_value',
#   'sma_100',
#   'bbands_lower',
#   'rsi',
#   'macd_hist'): 38.953766982985336,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'gold_open',
#   'stoch'): 38.317510167247384,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'gold_open',
#   'treasury_10_year'): 38.50087393743223,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'gold_open',
#   'rsi'): 38.11721295637746,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'gold_open',
#   'macd_hist'): 38.375837533797096,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'stoch',
#   'treasury_10_year'): 38.46509984380086,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'stoch',
#   'rsi'): 38.18436582048139,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'stoch',
#   'macd_hist'): 38.347915522593794,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'rsi'): 38.37155450076363,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'macd_hist'): 38.4926490909506,
#  ('today_value',
#   'sma_100',
#   'bbandwidth_100',
#   'rsi',
#   'macd_hist'): 38.34888071891273,
#  ('today_value',
#   'sma_100',
#   'gold_open',
#   'stoch',
#   'treasury_10_year'): 38.63219874265343,
#  ('today_value', 'sma_100', 'gold_open', 'stoch', 'rsi'): 38.30703001912791,
#  ('today_value',
#   'sma_100',
#   'gold_open',
#   'stoch',
#   'macd_hist'): 38.59093565206453,
#  ('today_value',
#   'sma_100',
#   'gold_open',
#   'treasury_10_year',
#   'rsi'): 38.327724646344954,
#  ('today_value',
#   'sma_100',
#   'gold_open',
#   'treasury_10_year',
#   'macd_hist'): 38.652140157741336,
#  ('today_value',
#   'sma_100',
#   'gold_open',
#   'rsi',
#   'macd_hist'): 38.357968012032146,
#  ('today_value',
#   'sma_100',
#   'stoch',
#   'treasury_10_year',
#   'rsi'): 38.41901209069396,
#  ('today_value',
#   'sma_100',
#   'stoch',
#   'treasury_10_year',
#   'macd_hist'): 38.520279885992785,
#  ('today_value', 'sma_100', 'stoch', 'rsi', 'macd_hist'): 38.41285570701747,
#  ('today_value',
#   'sma_100',
#   'treasury_10_year',
#   'rsi',
#   'macd_hist'): 38.54168070891935,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'obv',
#   'bbands_lower'): 39.118946056654636,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'obv',
#   'bbandwidth_100'): 38.97252860827563,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'obv',
#   'gold_open'): 39.061515446716506,
#  ('today_value', 'bbands_upper', 'sma_20', 'obv', 'stoch'): 38.956844369269575,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'obv',
#   'treasury_10_year'): 39.10056741874536,
#  ('today_value', 'bbands_upper', 'sma_20', 'obv', 'rsi'): 38.884229400118194,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'obv',
#   'macd_hist'): 39.15441653797453,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'bbandwidth_100'): 39.1535320239535,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'gold_open'): 39.06040059897145,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'stoch'): 38.965958620287616,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'treasury_10_year'): 39.13301909994748,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'rsi'): 39.06962884998307,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbands_lower',
#   'macd_hist'): 39.12483075056851,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbandwidth_100',
#   'gold_open'): 39.07468794916671,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbandwidth_100',
#   'stoch'): 38.82888227971315,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbandwidth_100',
#   'treasury_10_year'): 39.159482065927826,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbandwidth_100',
#   'rsi'): 38.766064427166285,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'bbandwidth_100',
#   'macd_hist'): 38.92533920182291,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'gold_open',
#   'stoch'): 38.90131299908258,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'gold_open',
#   'treasury_10_year'): 39.256824400110474,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'gold_open',
#   'rsi'): 38.948862854151535,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'gold_open',
#   'macd_hist'): 39.15360028531188,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'stoch',
#   'treasury_10_year'): 38.953590834401716,
#  ('today_value', 'bbands_upper', 'sma_20', 'stoch', 'rsi'): 38.82911053841863,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'stoch',
#   'macd_hist'): 38.96307554034044,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'treasury_10_year',
#   'rsi'): 38.99107684113509,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'treasury_10_year',
#   'macd_hist'): 39.291141721765335,
#  ('today_value',
#   'bbands_upper',
#   'sma_20',
#   'rsi',
#   'macd_hist'): 38.99064756535769,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbands_lower',
#   'bbandwidth_100'): 39.13871283492185,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbands_lower',
#   'gold_open'): 39.085355419469444,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbands_lower',
#   'stoch'): 39.06402909705055,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbands_lower',
#   'treasury_10_year'): 39.14389252717106,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbands_lower',
#   'rsi'): 39.11245897017322,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbands_lower',
#   'macd_hist'): 39.22474356095222,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbandwidth_100',
#   'gold_open'): 37.998188494996604,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbandwidth_100',
#   'stoch'): 38.354778818451656,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbandwidth_100',
#   'treasury_10_year'): 38.16937455680571,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbandwidth_100',
#   'rsi'): 38.04068453977379,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'bbandwidth_100',
#   'macd_hist'): 38.4823095121283,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'gold_open',
#   'stoch'): 38.34880014744781,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'gold_open',
#   'treasury_10_year'): 38.31268771359334,
#  ('today_value', 'bbands_upper', 'obv', 'gold_open', 'rsi'): 37.95964405075119,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'gold_open',
#   'macd_hist'): 38.48346589874961,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'stoch',
#   'treasury_10_year'): 38.48705975122674,
#  ('today_value', 'bbands_upper', 'obv', 'stoch', 'rsi'): 38.41256477862681,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'stoch',
#   'macd_hist'): 38.475051422344386,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'treasury_10_year',
#   'rsi'): 38.32126763271123,
#  ('today_value',
#   'bbands_upper',
#   'obv',
#   'treasury_10_year',
#   'macd_hist'): 38.51474154176745,
#  ('today_value', 'bbands_upper', 'obv', 'rsi', 'macd_hist'): 38.33512578824606,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'gold_open'): 39.09586453734898,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'stoch'): 38.9062018075397,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'treasury_10_year'): 39.1494439814497,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'rsi'): 38.92836935422511,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'bbandwidth_100',
#   'macd_hist'): 39.0821610124391,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'gold_open',
#   'stoch'): 38.95904130521615,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'gold_open',
#   'treasury_10_year'): 39.22282167543934,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'gold_open',
#   'rsi'): 39.0770668209724,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'gold_open',
#   'macd_hist'): 39.098292021683875,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'stoch',
#   'treasury_10_year'): 38.94171298229081,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'stoch',
#   'rsi'): 38.849619077972996,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'stoch',
#   'macd_hist'): 39.04317368643209,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'treasury_10_year',
#   'rsi'): 38.9558972027008,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'treasury_10_year',
#   'macd_hist'): 39.18112681969046,
#  ('today_value',
#   'bbands_upper',
#   'bbands_lower',
#   'rsi',
#   'macd_hist'): 39.061508722617106,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'gold_open',
#   'stoch'): 38.2577088503582,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'gold_open',
#   'treasury_10_year'): 38.596496514025084,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'gold_open',
#   'rsi'): 37.88622041173519,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'gold_open',
#   'macd_hist'): 38.23372900281288,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'stoch',
#   'treasury_10_year'): 38.55688176506601,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'stoch',
#   'rsi'): 38.24188764178768,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'stoch',
#   'macd_hist'): 38.3272068354546,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'rsi'): 38.266142325265335,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'treasury_10_year',
#   'macd_hist'): 38.47650899948478,
#  ('today_value',
#   'bbands_upper',
#   'bbandwidth_100',
#   'rsi',
#   'macd_hist'): 38.169980371066956,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'stoch',
#   'treasury_10_year'): 38.62311327093606,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'stoch',
#   'rsi'): 38.31078219850584,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'stoch',
#   'macd_hist'): 38.373732263994505,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'treasury_10_year',
#   'rsi'): 38.44029782330499,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'treasury_10_year',
#   'macd_hist'): 38.75108719339011,
#  ('today_value',
#   'bbands_upper',
#   'gold_open',
#   'rsi',
#   'macd_hist'): 38.34891951346253,
#  ('today_value',
#   'bbands_upper',
#   'stoch',
#   'treasury_10_year',
#   'rsi'): 38.56722408878973,
#  ('today_value',
#   'bbands_upper',
#   'stoch',
#   'treasury_10_year',
#   'macd_hist'): 38.61523566356797,
#  ('today_value',
#   'bbands_upper',
#   'stoch',
#   'rsi',
#   'macd_hist'): 38.21040729295238,
#  ('today_value',
#   'bbands_upper',
#   'treasury_10_year',
#   'rsi',
#   'macd_hist'): 38.605270929805606,
#  ('today_value',
#   'sma_20',
#   'obv',
#   'bbands_lower',
#   'bbandwidth_100'): 39.227271866490256,
#  ('today_value',
#   'sma_20',
#   'obv',
#   'bbands_lower',
#   'gold_open'): 39.19124667886534,
#  ('today_value', 'sma_20', 'obv', 'bbands_lower', 'stoch'): 39.057790247824414,
#  ...}
